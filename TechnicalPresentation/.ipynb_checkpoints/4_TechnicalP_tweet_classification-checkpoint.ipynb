# %% [markdown]
# # Classify pulled tweets from twitter, for major US airlines.

# %%
cd '/home/jovyan/GA_DSI/Projects/capstone'
# Out:
# /home/jovyan/GA_DSI/Projects/capstone

# %%
#!pip install gensim

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import gensim
import re
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

import lib.general_utilities as gu

from IPython.display import display
from IPython.display import Image
from sys import getsizeof
import matplotlib.pyplot as plt

processed_dir = 'data/processed_dataset_df/'

# %matplotlib inline

# %% [markdown]
# ### NOTE: Tweets were pulled using filtering by #airlinename.

# %% [markdown]
# ## Process pulled tweets by cleaning, removing stop words and lemmatizing.

# %%
# exclude name of airlines from the tweets. 
exclude = ['unitedairlines', 'americanairlines', 'southwestairlines',
           'virginamerica', 'usairways', 'jetblue', 'delta', 'flight', 'flights',
           'amp', 'amp;']

# load stopwords and exclude punctuation sets.
stop_words = list(ENGLISH_STOP_WORDS) + exclude
exclude_punctuation = set(string.punctuation) 
lemma = WordNetLemmatizer()

# %%
def tokenize(text):
    return(text.split())

# %%
def cleaner(text):
    # convert text to lowercase.
    text = text.lower()
    # remove www.* or https?://* to URL
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',text)
    # remove @username to AT_USER
    text = re.sub('@[^\s]+','',text)
    # remove additional white spaces
    text = re.sub('[\s]+', ' ', text)
    # Replace #word with word
    text = re.sub(r'#([^\s]+)', r'\1', text)
    # remove some punctuation symbols.
    text= ''.join(ch for ch in text if ch not in exclude_punctuation)
    # clean numbers.
    text = re.sub('&#39;','',text).lower()
    # trim
    text = text.strip('\'"')
    # trim any leading or trailing white spaces.
    text = text.strip()

    return(text)

# %%
# remove stopwords.
def remove_stopwords(text):
    '''
    remove english stop words
    '''
    token_text = tokenize(text)
    text = ' '.join(i for i in token_text if (i.strip() not in stop_words))
    return(text)

# %%
def lemmatize(text):
    
    # lemmatize: replace word with root of the word.
    text = ' '.join(lemma.lemmatize(word) for word in text.split())
    
    return(text)

# %%
#!pip install emoji

# %%
import emoji

# %%
# read in pickled emoji dictionary I created from emojis in the dataset. I want to use
# each emoji as an individual feature.
file = 'data/pickled/Emoticon_NB4/full_emoji_dict.obj'
emoji_dict = gu.read_pickle_obj(file)

# %%
def encode_emojis(text):
    input_txt = text
    for em in text:
        if em in emoji.UNICODE_EMOJI:
            try:
                input_txt = input_txt.replace(em, emoji_dict[em])
            except:
                # update dict.
                cnt = len(emoji_dict.keys())
                cnt+=1
                val='EMOJI_'+str(cnt)
                emoji_dict[em]=val
                input_txt = input_txt.replace(em, val)
                
    return(input_txt)

# %%
def extract_emojis(text):
    return(' '.join(word for word in text if word in emoji.UNICODE_EMOJI))

# %%
def declump_emojis_in_text(text):
    em_txt = text        
    for i in text:
        if (i in emoji.UNICODE_EMOJI):
            em_txt = em_txt.replace(i,' '+i)
        
    return(em_txt)

# %%
# Read in pulled tweets dataframe.
filename = 'data/pulled_tweets/PT_all_airlines_df'
pulledTweets_df = gu.read_pickle_obj(filename)

# Drop duplicate rows if any.
pulledTweets_df.drop_duplicates(subset='text', inplace=True)

pulledTweets_df.head(3)
# Out:
#           airline                date  \
# 0  UnitedAirlines 2018-01-09 21:19:36
# 1  UnitedAirlines 2018-01-09 21:06:39
# 2  UnitedAirlines 2018-01-09 21:02:07
#
#                                                 text
# 0  Kudos to the #unitedairlines staff for helping...
# 1  And the painful experience with  @united conti...
# 2  @united is the shittiest airline company I hav...

# %%
pulledTweets_df.columns
# Out:
# Index(['airline', 'date', 'text'], dtype='object')

# %%
# Process data using Natural Language Processing techniques: clean, remove stop words and lemmatize.
pulledTweets_df['Processed_tweet'] = pulledTweets_df['text'].apply(cleaner)
pulledTweets_df['Processed_tweet'] = pulledTweets_df['Processed_tweet'].apply(remove_stopwords)
pulledTweets_df['Processed_tweet'] = pulledTweets_df['Processed_tweet'].apply(lemmatize)

# %%
pulledTweets_df.head(20)
# Out:
#            airline                date  \
# 0   UnitedAirlines 2018-01-09 21:19:36
# 1   UnitedAirlines 2018-01-09 21:06:39
# 2   UnitedAirlines 2018-01-09 21:02:07
# 3   UnitedAirlines 2018-01-09 20:56:00
# 4   UnitedAirlines 2018-01-09 20:49:48
# 5   UnitedAirlines 2018-01-09 20:41:02
# 6   UnitedAirlines 2018-01-09 20:33:20
# 7   UnitedAirlines 2018-01-09 20:24:22
# 8   UnitedAirlines 2018-01-09 20:15:15
# 9   UnitedAirlines 2018-01-09 19:48:04
# 10  UnitedAirlines 2018-01-09 19:48:03
# 11  UnitedAirlines 2018-01-09 19:46:30
# 12  UnitedAirlines 2018-01-09 19:45:18
# 13  UnitedAirlines 2018-01-09 19:40:23
# 14  UnitedAirlines 2018-01-09 19:29:08
# 15  UnitedAirlines 2018-01-09 18:09:31
# 16  UnitedAirlines 2018-01-09 18:01:23
# 17  UnitedAirlines 2018-01-09 17:59:07
# 18  UnitedAirlines 2018-01-09 17:45:26
# 20  UnitedAirlines 2018-01-09 17:01:36
#
#                                                  text  \
# 0   Kudos to the #unitedairlines staff for helping...
# 1   And the painful experience with  @united conti...
# 2   @united is the shittiest airline company I hav...
# 3   Oh joy. You came home. #lostluggage #unitedair...
# 4   RT @officiParas: #UnitedAirlines Offers Custom...
# 5   #UnitedAirlines - still can’t understand why a...
# 6    My knees #unitedAIRLINES https://t.co/qErdox2Cht
# 7   @theweeknd cuts ties with H&amp;M over 'monkey...
# 8   A peek inside Classified, where CEOs and celeb...
# 9   Montreal, Canada to Phoenix, Arizona for only ...
# 10  Montreal, Canada to Phoenix, Arizona for only ...
# 11  RT @skygoflycom: United Star Alliance 'Queen' ...
# 12  United Star Alliance 'Queen' #unitedairlines #...
# 13  Glad I rushed to earlier flight, #UnitedAirlin...
# 14  #ups is not better than #unitedairlines #alita...
# 15  @united That's too bad. 😞 #YYJ would love some...
# 16  I am really pissed off with @united   Luggage ...
# 17  RT @matpag57: #UnitedAirlines - missed connect...
# 18  RT @LaurieLShaw: I’ve refused to fly #UnitedAi...
# 20  @USDOT please see recent tweets to @United abo...
#
#                                       Processed_tweet
# 0   kudos staff helping crazy reservation nice sen...
# 1   painful experience continues ask time lengthy ...
# 2   shittiest airline company experienced fuck nev...
# 3                        oh joy came home lostluggage
# 4   rt offer customer free checked bag travel tofr...
# 5   can’t understand 1 million miler 2mm board grp...
# 6                                                knee
# 7   cut tie hampm monkey ad blm equality4all monke...
# 8   peek inside classified ceo celebrity dine hidd...
# 9   montreal canada phoenix arizona 271 cad roundt...
# 10  montreal canada phoenix arizona 271 cad roundt...
# 11  rt united star alliance queen boeing 747 queen...
# 12  united star alliance queen boeing 747 queenoft...
# 13  glad rushed earlier youve got 30 min fix plane...
# 14         ups better alitalia company come handling…
# 15             thats bad 😞 yyj love service choices✈️
# 16  really pissed luggage missing jan 3 airline at...
# 17  rt missed connection sfo sts plane left early ...
# 18  rt i’ve refused fly year husband’s experience ...
# 20  recent tweet booked intl connecting w 20 min l...

# %%
# right now ☺️👍 will be a feature. I want features independent 
# as ☺️ and 👍. Let's declump them.

pulledTweets_df['emoji_enc_text'] = pulledTweets_df['Processed_tweet'].apply(declump_emojis_in_text)
# Now let's encode the emojis so we can use it in the vectorizer as a feature.
pulledTweets_df['emoji_enc_text'] = pulledTweets_df['emoji_enc_text'].apply(encode_emojis)

# create a new category 'emojis' with extracted emojis from tweets.
pulledTweets_df['emojis'] = pulledTweets_df['Processed_tweet'].apply(extract_emojis)

# %%
pulledTweets_df.head(20)
# Out:
#            airline                date  \
# 0   UnitedAirlines 2018-01-09 21:19:36
# 1   UnitedAirlines 2018-01-09 21:06:39
# 2   UnitedAirlines 2018-01-09 21:02:07
# 3   UnitedAirlines 2018-01-09 20:56:00
# 4   UnitedAirlines 2018-01-09 20:49:48
# 5   UnitedAirlines 2018-01-09 20:41:02
# 6   UnitedAirlines 2018-01-09 20:33:20
# 7   UnitedAirlines 2018-01-09 20:24:22
# 8   UnitedAirlines 2018-01-09 20:15:15
# 9   UnitedAirlines 2018-01-09 19:48:04
# 10  UnitedAirlines 2018-01-09 19:48:03
# 11  UnitedAirlines 2018-01-09 19:46:30
# 12  UnitedAirlines 2018-01-09 19:45:18
# 13  UnitedAirlines 2018-01-09 19:40:23
# 14  UnitedAirlines 2018-01-09 19:29:08
# 15  UnitedAirlines 2018-01-09 18:09:31
# 16  UnitedAirlines 2018-01-09 18:01:23
# 17  UnitedAirlines 2018-01-09 17:59:07
# 18  UnitedAirlines 2018-01-09 17:45:26
# 20  UnitedAirlines 2018-01-09 17:01:36
#
#                                                  text  \
# 0   Kudos to the #unitedairlines staff for helping...
# 1   And the painful experience with  @united conti...
# 2   @united is the shittiest airline company I hav...
# 3   Oh joy. You came home. #lostluggage #unitedair...
# 4   RT @officiParas: #UnitedAirlines Offers Custom...
# 5   #UnitedAirlines - still can’t understand why a...
# 6    My knees #unitedAIRLINES https://t.co/qErdox2Cht
# 7   @theweeknd cuts ties with H&amp;M over 'monkey...
# 8   A peek inside Classified, where CEOs and celeb...
# 9   Montreal, Canada to Phoenix, Arizona for only ...
# 10  Montreal, Canada to Phoenix, Arizona for only ...
# 11  RT @skygoflycom: United Star Alliance 'Queen' ...
# 12  United Star Alliance 'Queen' #unitedairlines #...
# 13  Glad I rushed to earlier flight, #UnitedAirlin...
# 14  #ups is not better than #unitedairlines #alita...
# 15  @united That's too bad. 😞 #YYJ would love some...
# 16  I am really pissed off with @united   Luggage ...
# 17  RT @matpag57: #UnitedAirlines - missed connect...
# 18  RT @LaurieLShaw: I’ve refused to fly #UnitedAi...
# 20  @USDOT please see recent tweets to @United abo...
#
#                                       Processed_tweet  \
# 0   kudos staff helping crazy reservation nice sen...
# 1   painful experience continues ask time lengthy ...
# 2   shittiest airline company experienced fuck nev...
# 3                        oh joy came home lostluggage
# 4   rt offer customer free checked bag travel tofr...
# 5   can’t understand 1 million miler 2mm board grp...
# 6                                                knee
# 7   cut tie hampm monkey ad blm equality4all monke...
# 8   peek inside classified ceo celebrity dine hidd...
# 9   montreal canada phoenix arizona 271 cad roundt...
# 10  montreal canada phoenix arizona 271 cad roundt...
# 11  rt united star alliance queen boeing 747 queen...
# 12  united star alliance queen boeing 747 queenoft...
# 13  glad rushed earlier youve got 30 min fix plane...
# 14         ups better alitalia company come handling…
# 15             thats bad 😞 yyj love service choices✈️
# 16  really pissed luggage missing jan 3 airline at...
# 17  rt missed connection sfo sts plane left early ...
# 18  rt i’ve refused fly year husband’s experience ...
# 20  recent tweet booked intl connecting w 20 min l...
#
#                                        emoji_enc_text emojis
# 0   kudos staff helping crazy reservation nice sen...
# 1   painful experience continues ask time lengthy ...
# 2   shittiest airline company experienced fuck nev...
# 3                        oh joy came home lostluggage
# 4   rt offer customer free checked bag travel tofr...
# 5   can’t understand 1 million miler 2mm board grp...
# 6                                                knee
# 7   cut tie hampm monkey ad blm equality4all monke...
# 8   peek inside classified ceo celebrity dine hidd...
# 9   montreal canada phoenix arizona 271 cad roundt...
# 10  montreal canada phoenix arizona 271 cad roundt...
# 11  rt united star alliance queen boeing 747 queen...
# 12  united star alliance queen boeing 747 queenoft...
# 13  glad rushed earlier youve got 30 min fix plane...
# 14         ups better alitalia company come handling…
# 15  thats bad  EMOJI_41 yyj love service choices E...    😞 ✈
# 16  really pissed luggage missing jan 3 airline at...
# 17  rt missed connection sfo sts plane left early ...
# 18  rt i’ve refused fly year husband’s experience ...
# 20  recent tweet booked intl connecting w 20 min l...

# %%
for row in range(100,106):
    print('Tweet: ')
    # Some tweets have \n - newlines, remove so it displays well.
    text = pulledTweets_df.text[pulledTweets_df.emojis!=''].values[row]
    text = text.replace('\n','')
    print('RAW TWEET: ', text, '\n')
    print('PROCESSED TWEET: ', pulledTweets_df.Processed_tweet[pulledTweets_df.emojis!=''].values[row], '\n')
    print('EMOJI ENC TWEET: ', pulledTweets_df.emoji_enc_text[pulledTweets_df.emojis!=''].values[row], '\n\n')
# Out:
# Tweet:
# RAW TWEET:  From https://t.co/vIwrgN5xSaReady to go.. ✈️😍💯 #AmericanAirlines #Thenewamerican #B737 #intheair #americanflight #aa #flights #saturday #intapic #instaimag #photooftheday #likes #zoom #crew #pilots #crewamerican #honduras #hn #aiport #iphonecamera #newphoto #inlove #newcap… https://t.co/BhaD0tVyKC
#
# PROCESSED TWEET:  ready ✈️😍💯 thenewamerican b737 intheair americanflight aa saturday intapic instaimag photooftheday like zoom crew pilot crewamerican honduras hn aiport iphonecamera newphoto inlove newcap…
#
# EMOJI ENC TWEET:  ready  EMOJI_7️ EMOJI_11 EMOJI_90 thenewamerican b737 intheair americanflight aa saturday intapic instaimag photooftheday like zoom crew pilot crewamerican honduras hn aiport iphonecamera newphoto inlove newcap…
#
#
# Tweet:
# RAW TWEET:  #AmericanAirlines  you have really dropped the ball with flight 997. You have known it was delayed since 6 yet you didn’t bother the get a backup crew here! You have a lot of unhappy customers! 😡
#
# PROCESSED TWEET:  really dropped ball 997 known delayed 6 didn’t bother backup crew lot unhappy customer 😡
#
# EMOJI ENC TWEET:  really dropped ball 997 known delayed 6 didn’t bother backup crew lot unhappy customer  EMOJI_4
#
#
# Tweet:
# RAW TWEET:  Have a great weekend ✈❤✈#avgeek #AmericanAirlines https://t.co/l2XjbCmeUS
#
# PROCESSED TWEET:  great weekend ✈❤✈ avgeek
#
# EMOJI ENC TWEET:  great weekend   EMOJI_7 EMOJI_1  EMOJI_7 avgeek
#
#
# Tweet:
# RAW TWEET:  RT @GreatSeatsMIA: #SamSmith will be performing live at #AmericanAirlines Arena on July 14th, 2018! 🎶Call or Email 👉305.395.4488/ Info@Gre…
#
# PROCESSED TWEET:  rt samsmith performing live arena july 14th 2018 🎶 email 👉3053954488 info
#
# EMOJI ENC TWEET:  rt samsmith performing live arena july 14th 2018  EMOJI_170 email  EMOJI_983053954488 info
#
#
# Tweet:
# RAW TWEET:  RT @GreatSeatsMIA: #AndreaBocelli will be performing at #AmericanAirlines Arena on #February 11th, 2018!Call or Email 👉305.395.4488/ Info@…
#
# PROCESSED TWEET:  rt andreabocelli performing arena february 11th 2018 email 👉3053954488 info
#
# EMOJI ENC TWEET:  rt andreabocelli performing arena february 11th 2018 email  EMOJI_983053954488 info
#
#
# Tweet:
# RAW TWEET:  RT @GreatSeatsMIA: The Nicky Jam concert is scheduled for #February 10th, 2018 at #AmericanAirlines Arena😎Call or Email👉305.395.4488/ Info…
#
# PROCESSED TWEET:  rt nicky jam concert scheduled february 10th 2018 arena😎 email👉3053954488 info…
#
# EMOJI ENC TWEET:  rt nicky jam concert scheduled february 10th 2018 arena EMOJI_18 email EMOJI_983053954488 info…

# %% [markdown]
# ## Pickle processed pulled tweets.

# %%
# Update emoji dict. Eventually unicode-escape this.
file = 'data/pickled/Emoticon_NB4/full_emoji_dict.obj'
gu.pickle_obj(file, emoji_dict)

# %%
# pickle pulled data.
filename = processed_dir+'pulledTweetsCleanedLemmaEmEnc_df'
gu.pickle_obj(filename,pulledTweets_df)

# %% [markdown]
# ## Use best grid searched Naive Bayes and Logistic Regression models to classify tweets.

# %%
EmEnc_model_results_gs_df[EmEnc_model_results_gs_df.dataset=='lemmatized']
# Out:
#       dataset               model  tr_acc_score  tst_acc_score  \
# 6  lemmatized          NaiveBayes      0.902020       0.850046
# 7  lemmatized  LogisticRegression      0.936731       0.864438
#
#                                          pipe_object  \
# 6  GridSearchCV(cv=5, error_score='raise',\n     ...
# 7  GridSearchCV(cv=5, error_score='raise',\n     ...
#
#                                               y_pred  \
# 6  [1, 2, 1, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 2, 0, ...
# 7  [1, 1, 1, 0, 1, 0, 0, 2, 0, 0, 0, 1, 2, 2, 0, ...
#
#                                                ytest  \
# 6  [1, 1, 2, 0, 0, 0, 0, 2, 0, 0, 0, 1, 0, 2, 0, ...
# 7  [1, 1, 2, 0, 0, 0, 0, 2, 0, 0, 0, 1, 0, 2, 0, ...
#
#                                          ypred_proba
# 6  [[0.0691840852212, 0.774504066889, 0.156311847...
# 7  [[0.180051121496, 0.759980075461, 0.0599688030...

# %% [markdown]
# ### Use best models found for lemmatized data.

# %%
pipe_nb  =EmEnc_model_results_gs_df.get_value(6, 'pipe_object')
pipe_lr = EmEnc_model_results_gs_df.get_value(7, 'pipe_object')

# pickle models.
file1 = processed_dir+'pipe_nb_lemma.obj'
file2 = processed_dir+'pipe_lr_lemma.obj'
gu.pickle_obj(file1, pipe_nb)
gu.pickle_obj(file2, pipe_lr)

# %%
pipe_nb.best_params_, pipe_lr.best_params_
# Out:
# ({'model__alpha': 0.10000000000000001,
#   'vec__max_df': 0.95,
#   'vec__min_df': 5,
#   'vec__ngram_range': (1, 2)},
#  {'model__C': 1.0,
#   'vec__max_df': 0.95,
#   'vec__min_df': 5,
#   'vec__ngram_range': (1, 2)})

# %%
classes = {0:'negative', 1:'neutral', 2:'positive'}

# %%
# Naive Bayes
y_pred = pipe_nb.predict(pulledTweets_df.emoji_enc_text)
y_proba = pipe_nb.predict_proba(pulledTweets_df.emoji_enc_text)

pulledTweets_df['sentiment_predicted_nb']=[classes[y_pred[i]] for i in range(len(y_pred))]

# %%
# Logistic Regression.
y_pred = pipe_lr.predict(pulledTweets_df.emoji_enc_text)
y_proba = pipe_lr.predict_proba(pulledTweets_df.emoji_enc_text)

pulledTweets_df['sentiment_predicted_lr']=[classes[y_pred[i]] for i in range(len(y_pred))]

# %%
pulledTweets_df[['text', 'sentiment_predicted_nb', 'sentiment_predicted_lr', 'emojis']][:20]
# Out:
#                                                  text sentiment_predicted_nb  \
# 0   Kudos to the #unitedairlines staff for helping...               positive
# 1   And the painful experience with  @united conti...               negative
# 2   @united is the shittiest airline company I hav...               negative
# 3   Oh joy. You came home. #lostluggage #unitedair...               negative
# 4   RT @officiParas: #UnitedAirlines Offers Custom...                neutral
# 5   #UnitedAirlines - still can’t understand why a...               negative
# 6    My knees #unitedAIRLINES https://t.co/qErdox2Cht               negative
# 7   @theweeknd cuts ties with H&amp;M over 'monkey...               negative
# 8   A peek inside Classified, where CEOs and celeb...                neutral
# 9   Montreal, Canada to Phoenix, Arizona for only ...               negative
# 10  Montreal, Canada to Phoenix, Arizona for only ...               negative
# 11  RT @skygoflycom: United Star Alliance 'Queen' ...               positive
# 12  United Star Alliance 'Queen' #unitedairlines #...               negative
# 13  Glad I rushed to earlier flight, #UnitedAirlin...               negative
# 14  #ups is not better than #unitedairlines #alita...               negative
# 15  @united That's too bad. 😞 #YYJ would love some...               positive
# 16  I am really pissed off with @united   Luggage ...               negative
# 17  RT @matpag57: #UnitedAirlines - missed connect...               negative
# 18  RT @LaurieLShaw: I’ve refused to fly #UnitedAi...               positive
# 20  @USDOT please see recent tweets to @United abo...               negative
#
#    sentiment_predicted_lr emojis
# 0                positive
# 1                negative
# 2                negative
# 3                negative
# 4                negative
# 5                negative
# 6                 neutral
# 7                negative
# 8                 neutral
# 9                 neutral
# 10                neutral
# 11                neutral
# 12               negative
# 13               negative
# 14               negative
# 15               negative    😞 ✈
# 16               negative
# 17               negative
# 18               positive
# 20               negative

# %% [markdown]
# ### Pickle dataframe with processed and classified tweets.

# %%
# pickle classified data.
filename = processed_dir+'pulledTweetsProcessedAndClassified_df'
gu.pickle_obj(filename,pulledTweets_df)

# %% [markdown]
# ### Let's visualize the predictions for both models.

# %%
df = pulledTweets_df[pulledTweets_df.airline != 'USAirways']

# %%
# Airline sentiment using Naive Bayes.
sns.countplot(x="airline", hue="sentiment_predicted_nb", data = df)
plt.title('Public Sentiment for major U.S. airlines - using Naive Bayes model',
         fontsize=14)
plt.xlabel('major U.S. airlines', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation = 90)
plt.tight_layout()
plt.savefig('data/images/Pulled_Tweets/'+'NB_sentiment_classification_hist.png')

# %%
# Airline sentiment using Logistic Regression.
sns.countplot(x="airline", hue="sentiment_predicted_lr", data=df)
plt.title('Public Sentiment for major U.S. airlines - using Logistic Regression model',
         fontsize=14)
plt.xlabel('major U.S. airlines', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('data/images/Pulled_Tweets/'+'LR_sentiment_classification_hist.png')

# %%
# look at the count of values for the 3 categories.
pulledTweets_df.sentiment_predicted_nb.value_counts().plot(kind='bar', 
                                                           title = 'Classification using Naive Bayes model')
plt.savefig('data/images/Pulled_Tweets/'+'NB_class_hist.png')

# %%
# look at the count of values for the 3 categories.
pulledTweets_df.sentiment_predicted_lr.value_counts().plot(kind='bar', 
                                                           title = 'Classification using Logistic Regression model')
plt.savefig('data/images/Pulled_Tweets/'+'LR_class_hist.png')

# %%
for i in range(50):
    print('TWEET:\n', pulledTweets_df.date.values[i], '\n', pulledTweets_df.text.values[i], 
          '\n\nSentiment Prediction NB:\n', pulledTweets_df.sentiment_predicted_nb.values[i],
          '\nSentiment Prediction LR:\n', pulledTweets_df.sentiment_predicted_lr.values[i],
          '\n')
# Out:
# TWEET:
#  2018-01-09T21:19:36.000000000
#  Kudos to the #unitedairlines staff for helping us with our crazy reservations.  Nice send-off from CHS
#
# Sentiment Prediction NB:
#  positive
# Sentiment Prediction LR:
#  positive
#
# TWEET:
#  2018-01-09T21:06:39.000000000
#  And the painful experience with  @united continues as they ask us to take the time to fill out lengthy reports on their website and to relive the blissful experience again. Thanks for nothing #unitedairlines ! https://t.co/W9skVmOhZw
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T21:02:07.000000000
#  @united is the shittiest airline company I have ever experienced. Fuck #UnitedAirlines #neveragain #lieslieslies
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T20:56:00.000000000
#  Oh joy. You came home. #lostluggage #unitedairlines https://t.co/msJgTAjiz6 https://t.co/8fHuZntw7e
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T20:49:48.000000000
#  RT @officiParas: #UnitedAirlines Offers Customers Two Free Checked Bags on Travel To/From China and Hong Kong @united https://t.co/8C2GqPr0…
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T20:41:02.000000000
#  #UnitedAirlines - still can’t understand why as a 1 Million Miler (now almost 2MM) I board in Grp2 when non-revs board in Grp1. Thanks for letting me know how much my loyalty of 20 plus years is valued...
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T20:33:20.000000000
#  My knees #unitedAIRLINES https://t.co/qErdox2Cht
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T20:24:22.000000000
#  @theweeknd cuts ties with H&amp;M over 'monkey' ad
# https://t.co/VJZxCyalrn
# @TheRoot #BLM #Equality4All #Monkey @Diddy @hm #Canada #ToneDeaf #Jenner @pepsi  #UnitedAirlines @CBCMusic @PolarisPrize @TheJUNOAwards #MusicNews
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T20:15:15.000000000
#  A peek inside Classified, where CEOs and celebrities dine in a hidden restaurant at Newark Liberty International Airport. https://t.co/bpmhavKTSh #TableReady #speakeasy #UnitedAirlines #exclusive
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T19:48:04.000000000
#  Montreal, Canada to Phoenix, Arizona for only $271 CAD roundtrip with United. #UnitedAirlines #Montreal https://t.co/3PErNhmXZ0
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T19:48:03.000000000
#  Montreal, Canada to Phoenix, Arizona for only $271 CAD roundtrip with United. #UnitedAirlines #Montreal https://t.co/Kr1BvGXzXM
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T19:46:30.000000000
#  RT @skygoflycom: United Star Alliance 'Queen' #unitedairlines #boeing #747 #queenoftheskies #planespotting #dontgo https://t.co/2THoOMtay3…
#
# Sentiment Prediction NB:
#  positive
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T19:45:18.000000000
#  United Star Alliance 'Queen' #unitedairlines #boeing #747 #queenoftheskies #planespotting #dontgo https://t.co/2THoOMtay3 https://t.co/8C1DbVpYyI
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T19:40:23.000000000
#  Glad I rushed to earlier flight, #UnitedAirlines you've got 30 min to fix this plane's maintenance issue before this becomes a huge mistake. On the plus side, the guy next to me is playing old school game boy
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T19:29:08.000000000
#  #ups is not better than #unitedairlines #alitalia and other companies when it comes to handling… https://t.co/dyBX8HNZJg
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T18:09:31.000000000
#  @united That's too bad. 😞 #YYJ would love some more #UnitedAirlines service choices✈️
#
# Sentiment Prediction NB:
#  positive
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T18:01:23.000000000
#  I am really pissed off with @united   Luggage missing since Jan 3 and no one from the airline has made any attempt to explain the problem #unitedairlines does not care
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T17:59:07.000000000
#  RT @matpag57: #UnitedAirlines - missed connection SFO to STS, plane left early and will be 30 min early - why?
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T17:45:26.000000000
#  RT @LaurieLShaw: I’ve refused to fly #UnitedAirlines for years now and my husband’s experience this morning with his flight only confirms i…
#
# Sentiment Prediction NB:
#  positive
# Sentiment Prediction LR:
#  positive
#
# TWEET:
#  2018-01-09T17:01:36.000000000
#  @USDOT please see recent tweets to @United about how they booked an INTL connecting flight w a 20 min layover (to land,clear customs,clear security, get to the new gate). Airlines shouldn't treat people like this, let alone customers. How is allowed &amp; not #illegal?#UnitedAirlines
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T17:01:36.000000000
#  (9/9) #FlyDelta #FlyAmerican #Fly anything other than @United /its affiliates right now, bc #UnitedAirlines is acting like they dont give a flying f*** about customers/people.Dear #United, pls stop treating ppl this way &amp; improve your customer service.Thx. #MakeUnitedGreatAgain
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T17:01:35.000000000
#  (8/9) This was our experience with #UnitedAirlines &amp; not w regular reps, but w managers. #United is a complete scam; they are the #scum of the earth (and the sky!).This is the least “@United” organization I have ever experienced.This is how #UnitedAirlines “treats” it’s customers
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T17:01:33.000000000
#  (1/9) think my latest experience of flying with #UnitedAirlines from Mexico-&gt;Houston-&gt;New York may have just taken 5 years off my life (and maybe my face). After rescheduling our connecting #flight that had an hour of lag time, @united ...
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T16:56:57.000000000
#  United Airlines Denver Colorado Airport Transportation 720-535-6030 #denverairport #ColoradoAirport #UnitedAirlines https://t.co/v39LLAUNoU https://t.co/2cMF9ddlAk
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  positive
#
# TWEET:
#  2018-01-09T16:44:00.000000000
#  My luggage with essential medical supplies that could literally save my life  has been sitting at Newark  airport since Saturday with @united , while I wait in rural Guatemala praying not to get ill.
# #UnitedAirlines #Newark
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T16:25:34.000000000
#  @united #UnitedAirlines You need to make this right on so many levels.  My husband &amp; father-in-law are headed to SoCal on bereavement.
#
# @united gate agent to my husband for the major delay: “There is nothing we can do. The plane is bad; we can’t just make another plane appear...
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T16:22:48.000000000
#  RT @edwowen: @united Day 4 with #noluggage #zerocontact #Disgraceful #CUSTOMERSERVICEFAIL #unitedairlines
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T16:12:39.000000000
#  @united Day 4 with #noluggage #zerocontact #Disgraceful #CUSTOMERSERVICEFAIL #unitedairlines
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T15:48:46.000000000
#  Approaching Chicago #windowseat #chicago #fog #boeing #unitedairlines https://t.co/XWXQ3IC78w https://t.co/ijnhOA8WhU
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T15:19:13.000000000
#  I’ve refused to fly #UnitedAirlines for years now and my husband’s experience this morning with his flight only confirms it again.  What a disrespectful, rude company you have.  Customer service is awful.
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T15:02:47.000000000
#  UPDATE: was able to get on that @united flight last night however still had a HORRIBLE experience. Rude customer rep and was charged another $60 for a carry-on. United is the worse airline EVER and I hope you go bankrupt. #UnitedAirlines #MoneyGrubbingRipOff 😡😡😡
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T13:57:47.000000000
#  #UnitedAirlines Offers Customers Two Free Checked Bags on Travel To/From China and Hong Kong @united https://t.co/8C2GqPr0Jg https://t.co/VelO7tDmIv
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T13:56:27.000000000
#  Happiness is having an empty middle seat, said everyone except the owners &amp; administration of airlines. Of course, not having a middle seat all is nice too. #UnitedAirlines @united
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T13:34:21.000000000
#  Shout out to @united for providing snacks and drinks at the gate on our delayed flight! #UnitedAirlines #omnomnom
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T12:28:33.000000000
#  RT @w1nnersclub: #UnitedAirlines passenger undertakes dirty #protest to obtain full price ticket status https://t.co/CdS0I2Szxo https://t.c…
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T12:27:53.000000000
#  #UnitedAirlines passenger undertakes dirty #protest to obtain full price ticket status https://t.co/CdS0I2Szxo https://t.co/01eRhQPZZs
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T12:03:40.000000000
#  Stuck in London because #MEA @MEAAIRLIBAN and #UnitedAirlines @united are two bullshit companies. They don't give a damn about their customers.
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T10:41:19.000000000
#  #unitedAIRLINES - My sister &amp; family were rerouted due to weather on the east coast. There were 14 people in standby. A mean gate agent at Heathrow Gate 33 was no match for the UA Pilot on flight UA879.  The pilot refused to leave with empty seats and saw the bigger picture.
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T09:28:56.000000000
#  RT @ScottAnthonyUSA: ⚠️ #Squawk7700 General Emergency (AGAIN) for #UnitedAirlines #3839 (now returning to Reagan Intl) 🚨
#
# Flight UA3838 fro…
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T08:02:12.000000000
#  RT @Morpheous416: #UnitedAirlines
# I have someone for your new PR management team! https://t.co/ZAdF2h3Md5
#
# Sentiment Prediction NB:
#  positive
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T06:35:17.000000000
#  RT @kjcappie: So not only did #UnitedAirlines cancel my flight to GSP They rebooked me on a flight to CLT instead. But my first flight had…
#
# Sentiment Prediction NB:
#  neutral
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T05:43:27.000000000
#  #CurrentlyInYapState
#
# Effective today, United Airlines implements new flight schedule at the Yap International Airport.
#
# #YapState #FSM #UnitedAirlines https://t.co/Ce9HXd0Ar7
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T05:25:28.000000000
#  .@united took @AmericanAir on the way there and it was a dream. Will never fly #UnitedAirlines again.
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T05:10:55.000000000
#  So not only did #UnitedAirlines cancel my flight to GSP They rebooked me on a flight to CLT instead. But my first flight had an hour delay making me miss my connection. But don’t worry. They gave me a hotel coupon for a hotel I’m not even staying at and a food voucher I can’t use
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T04:11:39.000000000
#  Maybe leaving Aspen😒
# #UnitedAirlines :(
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T03:47:45.000000000
#  Flight delay in Aspen
# #UnitedAirlines
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T03:42:02.000000000
#  Non-stop from Los Angeles to Cancun, Mexico for only $232 roundtrip with United. #UnitedAirlines #LosAngeles https://t.co/JypeUEfTRn
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T03:22:40.000000000
#  When you are on a flight ✈️ but have to get that National Championship Football Game in! 🏈#ilovecollegefootball #thankgodforinflightwifi #unitedairlines #cfbnationalchampionship https://t.co/DXlwzCjqXQ
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  neutral
#
# TWEET:
#  2018-01-09T01:07:24.000000000
#  Alberta's New Approach To Drunk Driving LIVE
# https://t.co/z0tNuk39yi
# #Alberta #DrunkDriving #DontDrinkAndDrive #Law #Police #Drunk #Drinking
# #Alcohol #DUI #DWI #WeirdNews #Epiphany #UnitedAirlines
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative
#
# TWEET:
#  2018-01-09T01:00:14.000000000
#  Rep. Sheila Jackson Lee's reverse racism gets even funnier as it emerges the white woman she bumped off the plane is a human rights journalist. https://t.co/tjtfwEqBDC #UnitedAirlines #SheilaJacksonLee
#
# Sentiment Prediction NB:
#  negative
# Sentiment Prediction LR:
#  negative

# %% [markdown]
# ## Observations:
# Text classification can be very challenging, due to high levels of ambiguity.<br>
# Then add to that the erratic language used by tweeters and that just makes it harder.<br>
# Then the issue of training data to train a model arises. Most often we have data with no labels, which makes supervised learning for this kind of data challenging.
#
# This leads to my next exploration... unsupervised learning - Topic Modelling using LDA model.

# %% [markdown]
# ## [Next Notebook: LDA Topic Modeling](5_TechnicalP_LDA.ipynb)
