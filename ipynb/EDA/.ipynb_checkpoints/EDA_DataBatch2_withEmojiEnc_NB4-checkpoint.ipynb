# %%
cd '/home/jovyan/GA_DSI/Projects/capstone'
# Out:
# /home/jovyan/GA_DSI/Projects/capstone

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import pickle

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

from IPython.display import display
from sys import getsizeof
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# storing data directories for this notebook.
img_out_dir = 'data/images/EDA_NB2_emoji_encoding/'
data_out_dir = 'data/pickled/EDA_NB2_emoji_encoding/'

# used to prin t word cloud in twitter bird shape.
from PIL import Image
wc_image_mask = np.array(Image.open('data/twitter.png'))

# %matplotlib inline

# %% [markdown]
# ## Airline Sentiment Classification
#
# Dataset Description from Kaggle:<br>
# Classifies customer sentiment towards major U.S. airlines, based on twitter data. Tweets were scraped from February of 2015 and contributors were asked to classify tweets by positive, negative, and neutral categories, followed by categorizing negative reasons (such as “late flight” or “rude service”).
#
# The Kaggle Dataset contains tweets and categories for 14,640k airline related tweets, classified into one of 3 sentiment categories (positive, negative, neutral).
# <br>Let's see if I can accurately classify the tweet sentiment category based on the text.

# %% [markdown]
# ### EDA on last 6640 rows of dataset. Had to split rows since calculating the sum of the columns<br>used to kill the kernel.

# %%
# going to explore last 6640 rows but dataset has 14640. I get performance issues.

# %%
air_full_df = pd.read_csv("data/csvfiles/kaggle_airline_dataset.csv", encoding='utf-8')

# %%
air_full_df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
# look at last 6640 rows.
air_full_df = air_full_df.iloc[8000:, :]

# %%
# data size of full kaggle dataset.
air_full_df.shape
# Out:
# (6640, 15)

# %%
air_full_df.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
air_full_df.airline_sentiment.value_counts()
# Out:
# negative    4618
# neutral     1145
# positive     877
# Name: airline_sentiment, dtype: int64

# %%
# Airline sentiment.
sns.countplot(x="airline", hue="airline_sentiment", data=air_full_df)
plt.title('Public Sentiment for major U.S. airlines - Kaggle 2015 twitter dataset',
         fontsize=14)
plt.xlabel('major U.S. airlines', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.tight_layout()
plt.savefig(img_out_dir+'BM_airline_sentiment_hist.png')

# %%
# What are reasons for customer dissatisfaction?
# Explore this to make recommendations at the end from findings.

# %%
# plot negative reason value_counts.
neg_reason = air_full_df.negativereason[air_full_df.negativereason.notnull()]
neg_reason.value_counts()
# Out:
# Customer Service Issue         1677
# Late Flight                     801
# Can't Tell                      510
# Cancelled Flight                463
# Lost Luggage                    328
# Flight Booking Problems         271
# Flight Attendant Complaints     231
# Bad Flight                      218
# longlines                        86
# Damaged Luggage                  33
# Name: negativereason, dtype: int64

# %%
plt.figure(figsize=(5,6))
sns.countplot(x="negativereason", data=air_full_df)
plt.grid(0)
plt.xticks(rotation = 90, fontsize=12)
plt.title("Customer negative sentiment topics", fontsize=14)
plt.tight_layout()
plt.savefig(img_out_dir+'BM_customer_neg_sent_topics_hist.png')

# %%
# airlines 
air_full_df.airline.unique()
# Out:
# array(['Delta', 'US Airways', 'American'], dtype=object)

# %%
# data types
air_full_df.dtypes
# Out:
# tweet_id                          int64
# airline_sentiment                object
# airline_sentiment_confidence    float64
# negativereason                   object
# negativereason_confidence       float64
# airline                          object
# airline_sentiment_gold           object
# name                             object
# negativereason_gold              object
# retweet_count                     int64
# text                             object
# tweet_coord                      object
# tweet_created                    object
# tweet_location                   object
# user_timezone                    object
# dtype: object

# %%
# check for null values.
air_full_df.isnull().sum()
# Out:
# tweet_id                           0
# airline_sentiment                  0
# airline_sentiment_confidence       0
# negativereason                  2022
# negativereason_confidence       1490
# airline                            0
# airline_sentiment_gold          6617
# name                               0
# negativereason_gold             6621
# retweet_count                      0
# text                               0
# tweet_coord                     6233
# tweet_created                      0
# tweet_location                  2255
# user_timezone                   2284
# dtype: int64

# %%
# get subset with cols = ['airline', 'text', 'airline_sentiment', 'airline_sentiment:confidence']

# %%
sub_cols = ['text', 'airline_sentiment', 'airline_sentiment_confidence', 
            'negativereason', 'airline']
air_sub_df = air_full_df.loc[:, sub_cols]

# %%
del air_full_df

# %%
# look at the confidence of values for the 3 categories.
air_sub_df.airline_sentiment_confidence.plot(kind='hist', title='airline sentiment confidence level')
plt.grid(0)

# %%
(air_sub_df.airline_sentiment_confidence >= 0.7).sum(), air_sub_df.shape
# Out:
# (5112, (6640, 5))

# %%
# let's only keep tweets where the airline_sentiment_confidence is > 0.7

# %%
mask = air_sub_df.airline_sentiment_confidence >= 0.7

air_sub_df = air_sub_df.loc[mask,:]

# %%
# dataframe with airline sentiment data with 
air_sub_df.shape
# Out:
# (5112, 5)

# %%
# look at the count of values for the 3 categories.
air_sub_df.airline_sentiment.value_counts().plot(kind='bar')
plt.grid(0)

# %%
air_sub_df.head()
# Out:
#                                                    text airline_sentiment  \
# 8000  @JetBlue do you have any afternoon flights goi...           neutral
# 8001  @JetBlue I'm flying your airline just out of #...           neutral
# 8002  @JetBlue he loved the #natural #beefjerky snacks😉          positive
# 8004  @JetBlue who is he I must send a note!!! Too g...          positive
# 8006        @JetBlue can't seem to DM you guys.. JDHADP          negative
#
#       airline_sentiment_confidence          negativereason airline
# 8000                        1.0000                     NaN   Delta
# 8001                        1.0000                     NaN   Delta
# 8002                        0.7153                     NaN   Delta
# 8004                        1.0000                     NaN   Delta
# 8006                        1.0000  Customer Service Issue   Delta

# %%
air_sub_df[air_sub_df.airline_sentiment == 'positive']['text'][:10]
# Out:
# 8002    @JetBlue he loved the #natural #beefjerky snacks😉
# 8004    @JetBlue who is he I must send a note!!! Too g...
# 8007    @JetBlue - loving Capt Joe on our flight from ...
# 8010              @JetBlue It was fabulous! Very pleased.
# 8015    @JetBlue No worries. Time flew in the terminal...
# 8018                          @JetBlue I will. Thank you!
# 8028    @JetBlue Thanks for the reminder of a few olde...
# 8036    @JetBlue heading to Buffalo... trading the col...
# 8038    @JetBlue Of course U know I would like 2 lay y...
# 8042    @JetBlue OOH! Good one! Speaking of #MiAmore -...
# Name: text, dtype: object

# %%
air_sub_df[air_sub_df.airline_sentiment == 'negative']['text'][:10]
# Out:
# 8006          @JetBlue can't seem to DM you guys.. JDHADP
# 8008    @JetBlue Two delays.  A little proactive commu...
# 8020    @JetBlue poor storm customer service, 1hr take...
# 8022    @JetBlue before departure, while people who ar...
# 8025    @JetBlue has the worst customer service out of...
# 8026    @JetBlue what's up with the random delay on fl...
# 8027    @JetBlue I lost a day at the airport and off m...
# 8031            @JetBlue what is the reason for the delay
# 8058    @JetBlue dont really know what that means but ...
# 8062    @JetBlue I ❤️ Jetblue but i was on flt 277 fro...
# Name: text, dtype: object

# %%
air_sub_df[air_sub_df.airline_sentiment == 'neutral']['text'][:10]
# Out:
# 8000    @JetBlue do you have any afternoon flights goi...
# 8001    @JetBlue I'm flying your airline just out of #...
# 8011    @JetBlue I'll take 3 round trip tickets to the...
# 8029    @JetBlue can I switch my seat for my trip on S...
# 8034                        @JetBlue is flt 1202 delayed?
# 8039    @JetBlue Now ur asking for the heavy guns! You...
# 8040    @JetBlue well mine sure aren't anything to wri...
# 8043    @JetBlue well I'm not sure I'm that bold! lol ...
# 8046    @JetBlue and The from @WSJ Team to Offer In-#F...
# 8061         @JetBlue why don't you fly to #nashville? :(
# Name: text, dtype: object

# %%
# target.
y = air_sub_df['airline_sentiment']

# %%
# unique values of y.
y.unique()
# Out:
# array(['neutral', 'positive', 'negative'], dtype=object)

# %%
#*********** Let's try to look at the top words in each of the categories, using CountVectorizer() *************

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
from nltk.stem.porter import PorterStemmer
import emoji
import string

# %%
# exclude name of airlines from the tweets. 
exclude = ['virginamerica', 'united', 'southwestair', 'delta', 'usairways',
           'americanair', 'jetblue', 'southwest', 'flight', 'flights',
           'URL', 'AT_USER', 'amp', 'amp;']

# %%
# define stop words. Use the defined 'english' stop words. I will add the airline names to that.
stop_words = list(ENGLISH_STOP_WORDS)
stop_words.extend(exclude)
exclude_punctuation = set(string.punctuation)

# %%
# read in pickled emoji dictionary I created from emojis in the dataset. I want to use
# each emoji as an individual feature.
file = open('data/pickled/Emoticon_NB4/full_emoji_dict.obj','rb')
emoji_dict = pickle.load(file)
            
# I also made a reverse lookup dict.
file = open('data/pickled/Emoticon_NB4/reverse_lookup_full_emoji_dict.obj','rb')
reverse_lookup_emoji_dict = pickle.load(file)

# %%
print(emoji_dict)
# Out:
# {'❤': 'EMOJI_1', '☺': 'EMOJI_2', '👍': 'EMOJI_3', '😡': 'EMOJI_4', '😢': 'EMOJI_5', '💜': 'EMOJI_6', '✈': 'EMOJI_7', '🍷': 'EMOJI_8', '💺': 'EMOJI_9', '😊': 'EMOJI_10', '😍': 'EMOJI_11', '👌': 'EMOJI_12', '💕': 'EMOJI_13', '🌞': 'EMOJI_14', '😃': 'EMOJI_15', '😩': 'EMOJI_16', '😭': 'EMOJI_17', '😎': 'EMOJI_18', '🙉': 'EMOJI_19', '😁': 'EMOJI_20', '❄': 'EMOJI_21', '👏': 'EMOJI_22', '😂': 'EMOJI_23', '💗': 'EMOJI_24', '🍸': 'EMOJI_25', '😒': 'EMOJI_26', '👎': 'EMOJI_27', '😀': 'EMOJI_28', '😄': 'EMOJI_29', '😘': 'EMOJI_30', '👸': 'EMOJI_31', '🎀': 'EMOJI_32', '🌏': 'EMOJI_33', '😥': 'EMOJI_34', '😉': 'EMOJI_35', '✨': 'EMOJI_36', '😱': 'EMOJI_37', '🎉': 'EMOJI_38', '🙌': 'EMOJI_39', '💤': 'EMOJI_40', '😞': 'EMOJI_41', '♥': 'EMOJI_42', '👋': 'EMOJI_43', '✌': 'EMOJI_44', '🙏': 'EMOJI_45', '👿': 'EMOJI_46', '😔': 'EMOJI_47', '🙅': 'EMOJI_48', '🆖': 'EMOJI_49', '💩': 'EMOJI_50', '✔': 'EMOJI_51', '🌴': 'EMOJI_52', '✅': 'EMOJI_53', '❌': 'EMOJI_54', '👠': 'EMOJI_55', '😜': 'EMOJI_56', '😻': 'EMOJI_57', '😕': 'EMOJI_58', '😈': 'EMOJI_59', '😤': 'EMOJI_60', '💪': 'EMOJI_61', '😫': 'EMOJI_62', '💔': 'EMOJI_63', '😪': 'EMOJI_64', '😣': 'EMOJI_65', '😬': 'EMOJI_66', '💁': 'EMOJI_67', '😋': 'EMOJI_68', '😏': 'EMOJI_69', '😖': 'EMOJI_70', '🌟': 'EMOJI_71', '📱': 'EMOJI_72', '🍻': 'EMOJI_73', '💖': 'EMOJI_74', '😅': 'EMOJI_75', '💝': 'EMOJI_76', '🚫': 'EMOJI_77', '↔': 'EMOJI_78', '😷': 'EMOJI_79', '⭐': 'EMOJI_80', '🎵': 'EMOJI_81', '❗': 'EMOJI_82', '🐴': 'EMOJI_83', '😆': 'EMOJI_84', '😑': 'EMOJI_85', '🐩': 'EMOJI_86', '⤴': 'EMOJI_87', '☀': 'EMOJI_88', '👊': 'EMOJI_89', '💯': 'EMOJI_90', '😠': 'EMOJI_91', '☕': 'EMOJI_92', '📲': 'EMOJI_93', '👺': 'EMOJI_94', '🙈': 'EMOJI_95', '💘': 'EMOJI_96', '💙': 'EMOJI_97', '👉': 'EMOJI_98', '🚪': 'EMOJI_99', '😳': 'EMOJI_100', '😵': 'EMOJI_101', '🚶': 'EMOJI_102', '🔵': 'EMOJI_103', '😐': 'EMOJI_104', '👀': 'EMOJI_105', '🍅': 'EMOJI_106', '🆘': 'EMOJI_107', '⛄': 'EMOJI_108', '😓': 'EMOJI_109', '🎲': 'EMOJI_110', '⌚': 'EMOJI_111', '🐳': 'EMOJI_112', '⤵': 'EMOJI_113', '😮': 'EMOJI_114', '😲': 'EMOJI_115', '😦': 'EMOJI_116', '➡': 'EMOJI_117'}

# %%
print(reverse_lookup_emoji_dict)
# Out:
# {'EMOJI_1': '❤', 'EMOJI_2': '☺', 'EMOJI_3': '👍', 'EMOJI_4': '😡', 'EMOJI_5': '😢', 'EMOJI_6': '💜', 'EMOJI_7': '✈', 'EMOJI_8': '🍷', 'EMOJI_9': '💺', 'EMOJI_10': '😊', 'EMOJI_11': '😍', 'EMOJI_12': '👌', 'EMOJI_13': '💕', 'EMOJI_14': '🌞', 'EMOJI_15': '😃', 'EMOJI_16': '😩', 'EMOJI_17': '😭', 'EMOJI_18': '😎', 'EMOJI_19': '🙉', 'EMOJI_20': '😁', 'EMOJI_21': '❄', 'EMOJI_22': '👏', 'EMOJI_23': '😂', 'EMOJI_24': '💗', 'EMOJI_25': '🍸', 'EMOJI_26': '😒', 'EMOJI_27': '👎', 'EMOJI_28': '😀', 'EMOJI_29': '😄', 'EMOJI_30': '😘', 'EMOJI_31': '👸', 'EMOJI_32': '🎀', 'EMOJI_33': '🌏', 'EMOJI_34': '😥', 'EMOJI_35': '😉', 'EMOJI_36': '✨', 'EMOJI_37': '😱', 'EMOJI_38': '🎉', 'EMOJI_39': '🙌', 'EMOJI_40': '💤', 'EMOJI_41': '😞', 'EMOJI_42': '♥', 'EMOJI_43': '👋', 'EMOJI_44': '✌', 'EMOJI_45': '🙏', 'EMOJI_46': '👿', 'EMOJI_47': '😔', 'EMOJI_48': '🙅', 'EMOJI_49': '🆖', 'EMOJI_50': '💩', 'EMOJI_51': '✔', 'EMOJI_52': '🌴', 'EMOJI_53': '✅', 'EMOJI_54': '❌', 'EMOJI_55': '👠', 'EMOJI_56': '😜', 'EMOJI_57': '😻', 'EMOJI_58': '😕', 'EMOJI_59': '😈', 'EMOJI_60': '😤', 'EMOJI_61': '💪', 'EMOJI_62': '😫', 'EMOJI_63': '💔', 'EMOJI_64': '😪', 'EMOJI_65': '😣', 'EMOJI_66': '😬', 'EMOJI_67': '💁', 'EMOJI_68': '😋', 'EMOJI_69': '😏', 'EMOJI_70': '😖', 'EMOJI_71': '🌟', 'EMOJI_72': '📱', 'EMOJI_73': '🍻', 'EMOJI_74': '💖', 'EMOJI_75': '😅', 'EMOJI_76': '💝', 'EMOJI_77': '🚫', 'EMOJI_78': '↔', 'EMOJI_79': '😷', 'EMOJI_80': '⭐', 'EMOJI_81': '🎵', 'EMOJI_82': '❗', 'EMOJI_83': '🐴', 'EMOJI_84': '😆', 'EMOJI_85': '😑', 'EMOJI_86': '🐩', 'EMOJI_87': '⤴', 'EMOJI_88': '☀', 'EMOJI_89': '👊', 'EMOJI_90': '💯', 'EMOJI_91': '😠', 'EMOJI_92': '☕', 'EMOJI_93': '📲', 'EMOJI_94': '👺', 'EMOJI_95': '🙈', 'EMOJI_96': '💘', 'EMOJI_97': '💙', 'EMOJI_98': '👉', 'EMOJI_99': '🚪', 'EMOJI_100': '😳', 'EMOJI_101': '😵', 'EMOJI_102': '🚶', 'EMOJI_103': '🔵', 'EMOJI_104': '😐', 'EMOJI_105': '👀', 'EMOJI_106': '🍅', 'EMOJI_107': '🆘', 'EMOJI_108': '⛄', 'EMOJI_109': '😓', 'EMOJI_110': '🎲', 'EMOJI_111': '⌚', 'EMOJI_112': '🐳', 'EMOJI_113': '⤵', 'EMOJI_114': '😮', 'EMOJI_115': '😲', 'EMOJI_116': '😦', 'EMOJI_117': '➡'}

# %%
def encode_emojis(text):
    input_txt = text
    for word in text:
        if word in emoji.UNICODE_EMOJI:
            input_txt = input_txt.replace(word, emoji_dict[word])
    return(input_txt)

# %%
def extract_emojis(text):
    return(' '.join(word for word in text if word in emoji.UNICODE_EMOJI))

# %%
def tokenize(text):
    return(text.split())

# %%
def cleaner(text):
    
    # convert text to lowercase.
    text = text.lower()
    # remove www.* or https?://* to URL
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',text)
    # remove @username to AT_USER
    text = re.sub('@[^\s]+','',text)
    # remove additional white spaces
    text = re.sub('[\s]+', ' ', text)
    # Replace #word with word
    text = re.sub(r'#([^\s]+)', r'\1', text)
    # remove some punctuation symbols.
    text= ''.join(ch for ch in text if ch not in exclude_punctuation)
    # clean
    text = re.sub('&#39;','',text).lower()
    # trim
    text = text.strip('\'"')
    # trim any leading or trailing white spaces.
    text = text.strip()

    return(text)

# %%
# remove stopwords.
def remove_stopwords(text):
    '''
    remove english stop words
    '''
    word_lst = tokenize(text)
    out = [word.strip() for word in word_lst if word not in stop_words]   
    
    text = ' '.join(out)
    return(text)

# %%
def stemming(text):
    '''
    replaces words with its stem word (ie thanks-> thanks, fly->fli,...)
    '''
    ps = PorterStemmer()
    text = tokenize(text)
    text = ' '.join(ps.stem(word) for word in text)
    return(text)

# %%
def declump_emojis_in_text(text):
    em_txt = text        
    for i in text:
        if (i in emoji.UNICODE_EMOJI):
            em_txt = em_txt.replace(i,' '+i)
        
    return(em_txt)

# %% [markdown]
# ## Clean Text
# ```(eliminate web tags, punctuation, symbols...)```

# %%
air_sub_df.columns
# Out:
# Index(['text', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'airline'],
#       dtype='object')

# %%
# create a new category 'clean_text' with clean text.
air_sub_df['clean_text'] = air_sub_df['text'].apply(cleaner)

# %%
# Let's see what the clean data looks like.

# %%
air_sub_df[['clean_text', 'text']][y=='positive'][:10]
# Out:
#                                              clean_text  \
# 8002             he loved the natural beefjerky snacks😉
# 8004    who is he i must send a note too good for words
# 8007  loving capt joe on our flight from bos to sfo ...
# 8010                       it was fabulous very pleased
# 8015  no worries time flew in the terminal and now w...
# 8018                                   i will thank you
# 8028  thanks for the reminder of a few older flights...
# 8036  heading to buffalo trading the cold in boston ...
# 8038  of course u know i would like 2 lay you down i...
# 8042  ooh good one speaking of miamore  just know th...
#
#                                                    text
# 8002  @JetBlue he loved the #natural #beefjerky snacks😉
# 8004  @JetBlue who is he I must send a note!!! Too g...
# 8007  @JetBlue - loving Capt Joe on our flight from ...
# 8010            @JetBlue It was fabulous! Very pleased.
# 8015  @JetBlue No worries. Time flew in the terminal...
# 8018                        @JetBlue I will. Thank you!
# 8028  @JetBlue Thanks for the reminder of a few olde...
# 8036  @JetBlue heading to Buffalo... trading the col...
# 8038  @JetBlue Of course U know I would like 2 lay y...
# 8042  @JetBlue OOH! Good one! Speaking of #MiAmore -...

# %%
air_sub_df.loc[8002, 'text']
# Out:
# '@JetBlue he loved the #natural #beefjerky snacks😉'

# %%
air_sub_df.loc[8002, 'clean_text']
# Out:
# 'he loved the natural beefjerky snacks😉'

# %%
air_sub_df[['clean_text', 'text']][y=='negative'][:10]
# Out:
#                                              clean_text  \
# 8006                    cant seem to dm you guys jdhadp
# 8008  two delays a little proactive communication go...
# 8020  poor storm customer service 1hr takeoff delay ...
# 8022  before departure while people who are delayed ...
# 8025  has the worst customer service out of any airl...
# 8026  whats up with the random delay on flight 1729 ...
# 8027  i lost a day at the airport and off my trip i ...
# 8031                   what is the reason for the delay
# 8058  dont really know what that means but this isnt...
# 8062  i ❤️ jetblue but i was on flt 277 from fll to ...
#
#                                                    text
# 8006        @JetBlue can't seem to DM you guys.. JDHADP
# 8008  @JetBlue Two delays.  A little proactive commu...
# 8020  @JetBlue poor storm customer service, 1hr take...
# 8022  @JetBlue before departure, while people who ar...
# 8025  @JetBlue has the worst customer service out of...
# 8026  @JetBlue what's up with the random delay on fl...
# 8027  @JetBlue I lost a day at the airport and off m...
# 8031          @JetBlue what is the reason for the delay
# 8058  @JetBlue dont really know what that means but ...
# 8062  @JetBlue I ❤️ Jetblue but i was on flt 277 fro...

# %%
air_sub_df.loc[8062, 'text']
# Out:
# '@JetBlue I ❤️ Jetblue but i was on flt 277 from fll to sfo. tke off was over 1 hr Late Flight, div to phx &amp; got in 2 hrs Late Flight. What will be done?'

# %%
air_sub_df.loc[8062, 'clean_text']
# Out:
# 'i ❤️ jetblue but i was on flt 277 from fll to sfo tke off was over 1 hr late flight div to phx amp got in 2 hrs late flight what will be done'

# %%
air_sub_df[['clean_text', 'text']][y=='neutral'][:10]
# Out:
#                                              clean_text  \
# 8000  do you have any afternoon flights going from b...
# 8001           im flying your airline just out of lga 😷
# 8011  ill take 3 round trip tickets to the closest w...
# 8029         can i switch my seat for my trip on sunday
# 8034                                is flt 1202 delayed
# 8039  now ur asking for the heavy guns you know iwou...
# 8040  well mine sure arent anything to write home about
# 8043  well im not sure im that bold lol or are you s...
# 8046  and the from team to offer inflight access to ...
# 8061                      why dont you fly to nashville
#
#                                                    text
# 8000  @JetBlue do you have any afternoon flights goi...
# 8001  @JetBlue I'm flying your airline just out of #...
# 8011  @JetBlue I'll take 3 round trip tickets to the...
# 8029  @JetBlue can I switch my seat for my trip on S...
# 8034                      @JetBlue is flt 1202 delayed?
# 8039  @JetBlue Now ur asking for the heavy guns! You...
# 8040  @JetBlue well mine sure aren't anything to wri...
# 8043  @JetBlue well I'm not sure I'm that bold! lol ...
# 8046  @JetBlue and The from @WSJ Team to Offer In-#F...
# 8061       @JetBlue why don't you fly to #nashville? :(

# %%
air_sub_df.loc[8001, 'text']
# Out:
# "@JetBlue I'm flying your airline just out of #LGA 😷"

# %%
air_sub_df.loc[8001, 'clean_text']
# Out:
# 'im flying your airline just out of lga 😷'

# %%
# users clump emojis together with words. I want to vectorize them as 
# separate individual features - where each unique emoji in training corpus 
# is a feature. 

# NOTE: later maybe I should change this so many more emojis are incorporated as
# features - not just the ones in the training corpus.

# %%
# example of clumped emoji.
air_sub_df.loc[8002, 'clean_text']
# Out:
# 'he loved the natural beefjerky snacks😉'

# %%
air_sub_df.loc[8202, 'clean_text']
# Out:
# 'thank you very very much 💙💙'

# %%
# right now snacks😉 will be a feature. I want features independent 
# as snack and 😉. Let's declump them.

air_sub_df['clean_text'] = air_sub_df['clean_text'].apply(declump_emojis_in_text)

# %%
air_sub_df.loc[8002, 'clean_text']
# Out:
# 'he loved the natural beefjerky snacks 😉'

# %%
air_sub_df.loc[8202, 'clean_text']
# Out:
# 'thank you very very much   💙  💙'

# %%
# notice now the emoji is a separate feature.

# %%
# Now let's encode the emojis so we can use it in the vectorizer as a feature.
air_sub_df['clean_text'] = air_sub_df['clean_text'].apply(encode_emojis)

# %%
air_sub_df.loc[8002, 'clean_text']
# Out:
# 'he loved the natural beefjerky snacksEMOJI_35'

# %%
air_sub_df.loc[8202, 'clean_text']
# Out:
# 'thank you very very much EMOJI_97EMOJI_97'

# %%
# The emojis from above are now encoded.

# %%
# now I want to create a separate col that stores a list of emojis
# in the text, if any are present. This may be useful for exploring
# sentiment and emoji relationships further.

# %%
# create a new category 'emojis' with emojis.
air_sub_df['emojis'] = air_sub_df['text'].apply(extract_emojis)

# %%
air_sub_df[air_sub_df['emojis']!=''][:5]
# Out:
#                                                    text airline_sentiment  \
# 8001  @JetBlue I'm flying your airline just out of #...           neutral
# 8002  @JetBlue he loved the #natural #beefjerky snacks😉          positive
# 8062  @JetBlue I ❤️ Jetblue but i was on flt 277 fro...          negative
# 8121  @JetBlue haha no need to apologize 😁 I'll be F...          positive
# 8131  @JetBlue can't wait! I'll be the one who can't...          positive
#
#       airline_sentiment_confidence negativereason airline  \
# 8001                        1.0000            NaN   Delta
# 8002                        0.7153            NaN   Delta
# 8062                        1.0000    Late Flight   Delta
# 8121                        1.0000            NaN   Delta
# 8131                        1.0000            NaN   Delta
#
#                                              clean_text emojis
# 8001    im flying your airline just out of lga EMOJI_79      😷
# 8002      he loved the natural beefjerky snacksEMOJI_35      😉
# 8062  i EMOJI_1️ jetblue but i was on flt 277 from f...      ❤
# 8121  haha no need to apologize EMOJI_20 ill be flig...      😁
# 8131  cant wait ill be the one who cant contain hers...      😄

# %% [markdown]
# ## Reduce dimensionality - using english stop words
# ```(eliminating english stop words that typically don't impart much meaning like prepositions, pronouns... I will also remove twitter handle and urls encoded above, in the cleaner method, as AT_USER and URL.```

# %%
# create a new category 'stopw_clean_text' to store reduced dimensionality text,
# by eliminating english stop words.
air_sub_df['stopw_clean_text'] = air_sub_df['clean_text'].apply(remove_stopwords)

# %%
air_sub_df[['stopw_clean_text', 'clean_text']][y=='positive'][:10]
# Out:
#                                        stopw_clean_text  \
# 8002            loved natural beefjerky snacks EMOJI_35
# 8004                               send note good words
# 8007                    loving capt joe bos sfo 633 fun
# 8010                                   fabulous pleased
# 8015           worries time flew terminal taking thanks
# 8018                                              thank
# 8028  thanks reminder older id taken easy access add...
# 8036  heading buffalo trading cold boston colder buf...
# 8038  course u know like 2 lay bedofroses long theyr...
# 8042  ooh good speaking miamore just know iadore lov...
#
#                                              clean_text
# 8002     he loved the natural beefjerky snacks EMOJI_35
# 8004    who is he i must send a note too good for words
# 8007  loving capt joe on our flight from bos to sfo ...
# 8010                       it was fabulous very pleased
# 8015  no worries time flew in the terminal and now w...
# 8018                                   i will thank you
# 8028  thanks for the reminder of a few older flights...
# 8036  heading to buffalo trading the cold in boston ...
# 8038  of course u know i would like 2 lay you down i...
# 8042  ooh good one speaking of miamore  just know th...

# %%
air_sub_df.loc[8002, 'clean_text']
# Out:
# 'he loved the natural beefjerky snacks EMOJI_35'

# %%
air_sub_df.loc[8002, 'stopw_clean_text']
# Out:
# 'loved natural beefjerky snacks EMOJI_35'

# %%
air_sub_df[['stopw_clean_text', 'clean_text']][y=='negative'][:10]
# Out:
#                                        stopw_clean_text  \
# 8006                                     dm guys jdhadp
# 8008  delays little proactive communication goes lon...
# 8020  poor storm customer service 1hr takeoff delay ...
# 8022       departure people delayed 200 compensate time
# 8025  worst customer service airline company dontfly...
# 8026         whats random delay 1729 chance false alarm
# 8027    lost day airport trip compensated inconvenience
# 8031                                       reason delay
# 8058  dont really know means isnt best firsttimeflyi...
# 8062  EMOJI_1️ flt 277 fll sfo tke 1 hr late div phx...
#
#                                              clean_text
# 8006                    cant seem to dm you guys jdhadp
# 8008  two delays a little proactive communication go...
# 8020  poor storm customer service 1hr takeoff delay ...
# 8022  before departure while people who are delayed ...
# 8025  has the worst customer service out of any airl...
# 8026  whats up with the random delay on flight 1729 ...
# 8027  i lost a day at the airport and off my trip i ...
# 8031                   what is the reason for the delay
# 8058  dont really know what that means but this isnt...
# 8062  i  EMOJI_1️ jetblue but i was on flt 277 from ...

# %%
air_sub_df.loc[8062, 'clean_text']
# Out:
# 'i  EMOJI_1️ jetblue but i was on flt 277 from fll to sfo tke off was over 1 hr late flight div to phx amp got in 2 hrs late flight what will be done'

# %%
air_sub_df.loc[8062, 'stopw_clean_text']
# Out:
# 'EMOJI_1️ flt 277 fll sfo tke 1 hr late div phx got 2 hrs late'

# %%
air_sub_df[['stopw_clean_text', 'clean_text']][y=='neutral'][:10]
# Out:
#                                        stopw_clean_text  \
# 8000              afternoon going bqn jfk early morning
# 8001                im flying airline just lga EMOJI_79
# 8011  ill 3 round trip tickets closest warmest place...
# 8029                            switch seat trip sunday
# 8034                                   flt 1202 delayed
# 8039  ur asking heavy guns know iwoulddoanythingforl...
# 8040                              sure arent write home
# 8043         im sure im bold lol saying didnt believe p
# 8046  team offer inflight access journal digital jou...
# 8061                                 dont fly nashville
#
#                                              clean_text
# 8000  do you have any afternoon flights going from b...
# 8001   im flying your airline just out of lga  EMOJI_79
# 8011  ill take 3 round trip tickets to the closest w...
# 8029         can i switch my seat for my trip on sunday
# 8034                                is flt 1202 delayed
# 8039  now ur asking for the heavy guns you know iwou...
# 8040  well mine sure arent anything to write home about
# 8043  well im not sure im that bold lol or are you s...
# 8046  and the from team to offer inflight access to ...
# 8061                      why dont you fly to nashville

# %%
air_sub_df.loc[8001, 'clean_text']
# Out:
# 'im flying your airline just out of lga  EMOJI_79'

# %%
air_sub_df.loc[8001, 'stopw_clean_text']
# Out:
# 'im flying airline just lga EMOJI_79'

# %% [markdown]
# ## Further reduce dimensionality - using stemming
# ```(Stemming attempts to find the root of the word by chopping off the end, like thanks becoms thank...)```

# %%
# create a new category 'stem_stopw_clean_text' to store reduced dimensionality text,
# by finding root of words.
air_sub_df['stem_stopw_clean_text'] = air_sub_df['stopw_clean_text'].apply(stemming)

# %%
air_sub_df[['stem_stopw_clean_text', 'stopw_clean_text']][y=='positive'][:10]
# Out:
#                                   stem_stopw_clean_text  \
# 8002                love natur beefjerki snack emoji_35
# 8004                                send note good word
# 8007                       love capt joe bo sfo 633 fun
# 8010                                        fabul pleas
# 8015                  worri time flew termin take thank
# 8018                                              thank
# 8028  thank remind older id taken easi access add po...
# 8036  head buffalo trade cold boston colder buffalo ...
# 8038  cours u know like 2 lay bedofros long theyr mi...
# 8042  ooh good speak miamor just know iador love lov...
#
#                                        stopw_clean_text
# 8002            loved natural beefjerky snacks EMOJI_35
# 8004                               send note good words
# 8007                    loving capt joe bos sfo 633 fun
# 8010                                   fabulous pleased
# 8015           worries time flew terminal taking thanks
# 8018                                              thank
# 8028  thanks reminder older id taken easy access add...
# 8036  heading buffalo trading cold boston colder buf...
# 8038  course u know like 2 lay bedofroses long theyr...
# 8042  ooh good speaking miamore just know iadore lov...

# %%
air_sub_df.loc[8002, 'stopw_clean_text']
# Out:
# 'loved natural beefjerky snacks EMOJI_35'

# %%
air_sub_df.loc[8002, 'stem_stopw_clean_text']
# Out:
# 'love natur beefjerki snack emoji_35'

# %%
air_sub_df[['stem_stopw_clean_text', 'stopw_clean_text']][y=='negative'][:10]
# Out:
#                                   stem_stopw_clean_text  \
# 8006                                      dm guy jdhadp
# 8008  delay littl proactiv commun goe long way howha...
# 8020  poor storm custom servic 1hr takeoff delay wai...
# 8022              departur peopl delay 200 compens time
# 8025     worst custom servic airlin compani dontflythem
# 8026            what random delay 1729 chanc fals alarm
# 8027            lost day airport trip compens inconveni
# 8031                                       reason delay
# 8058  dont realli know mean isnt best firsttimeflyin...
# 8062  emoji_1️ flt 277 fll sfo tke 1 hr late div phx...
#
#                                        stopw_clean_text
# 8006                                     dm guys jdhadp
# 8008  delays little proactive communication goes lon...
# 8020  poor storm customer service 1hr takeoff delay ...
# 8022       departure people delayed 200 compensate time
# 8025  worst customer service airline company dontfly...
# 8026         whats random delay 1729 chance false alarm
# 8027    lost day airport trip compensated inconvenience
# 8031                                       reason delay
# 8058  dont really know means isnt best firsttimeflyi...
# 8062  EMOJI_1️ flt 277 fll sfo tke 1 hr late div phx...

# %%
air_sub_df.loc[8062, 'stopw_clean_text']
# Out:
# 'EMOJI_1️ flt 277 fll sfo tke 1 hr late div phx got 2 hrs late'

# %%
air_sub_df.loc[8062, 'stem_stopw_clean_text']
# Out:
# 'emoji_1️ flt 277 fll sfo tke 1 hr late div phx got 2 hr late'

# %%
air_sub_df[['stem_stopw_clean_text', 'stopw_clean_text']][y=='neutral'][:10]
# Out:
#                                   stem_stopw_clean_text  \
# 8000                    afternoon go bqn jfk earli morn
# 8001                    im fli airlin just lga emoji_79
# 8011  ill 3 round trip ticket closest warmest place ...
# 8029                            switch seat trip sunday
# 8034                                     flt 1202 delay
# 8039  ur ask heavi gun know iwoulddoanythingforlov b...
# 8040                              sure arent write home
# 8043             im sure im bold lol say didnt believ p
# 8046   team offer inflight access journal digit journal
# 8061                                   dont fli nashvil
#
#                                        stopw_clean_text
# 8000              afternoon going bqn jfk early morning
# 8001                im flying airline just lga EMOJI_79
# 8011  ill 3 round trip tickets closest warmest place...
# 8029                            switch seat trip sunday
# 8034                                   flt 1202 delayed
# 8039  ur asking heavy guns know iwoulddoanythingforl...
# 8040                              sure arent write home
# 8043         im sure im bold lol saying didnt believe p
# 8046  team offer inflight access journal digital jou...
# 8061                                 dont fly nashville

# %%
air_sub_df.loc[8001, 'stopw_clean_text']
# Out:
# 'im flying airline just lga EMOJI_79'

# %%
air_sub_df.loc[8001, 'stem_stopw_clean_text']
# Out:
# 'im fli airlin just lga emoji_79'

# %%
# Let's make a word cloud to visualize the clean text data.

# %%
def make_wordcloud(data, title, filename, mask):
    plt.figure(figsize=(7,7))
    im = WordCloud(max_words=300, mask=mask).generate(' '.join(i for i in data))
    plt.grid(0)
    plt.title(title, fontsize=14)
    im.to_file(img_out_dir+filename)
    plt.imshow(im)

# %% [markdown]
# ## Positive class

# %%
# only cleaned text.

# twitter logo.
mask = wc_image_mask

data = air_sub_df['clean_text'][y=='positive']
title = "Positive sentiment:  cleaned text"
filename = 'WordCld_pos_sent_cleantext.png'
make_wordcloud(data, title, filename, mask)

# text with added elimination of stopwords.
data = air_sub_df['stopw_clean_text'][y=='positive']
title = "Positive sentiment:  added stopwords"
filename = 'WordCld_pos_sent_stopwused.png'
make_wordcloud(data, title, filename, mask)

data = air_sub_df['stem_stopw_clean_text'][y=='positive']
title = "Positive sentiment:  added stemming"
filename = 'WordCld_pos_sent_stemused.png'
make_wordcloud(data, title, filename, mask)

# %% [markdown]
# ## Negative class

# %%
# only cleaned text.

# twitter logo.
mask = wc_image_mask

data = air_sub_df['clean_text'][y=='negative']
title = "Negative sentiment:  cleaned text"
filename = 'WordCld_neg_sent_cleantext.png'
make_wordcloud(data, title, filename, mask)

# text with added elimination of stopwords.
data = air_sub_df['stopw_clean_text'][y=='negative']
title = "Negative sentiment:  added stopwords"
filename = 'WordCld_neg_sent_stopwused.png'
make_wordcloud(data, title, filename, mask)

data = air_sub_df['stem_stopw_clean_text'][y=='negative']
title = "Negative sentiment:  added stemming"
filename = 'WordCld_neg_sent_stemused.png'
make_wordcloud(data, title, filename, mask)

# %%
# only cleaned text.

# twitter logo.
mask = wc_image_mask

data = air_sub_df['clean_text'][y=='neutral']
title = "Neutral sentiment:  cleaned text"
filename = 'WordCld_neut_sent_cleantext.png'
make_wordcloud(data, title, filename, mask)

# text with added elimination of stopwords.
data = air_sub_df['stopw_clean_text'][y=='neutral']
title = "Neutral sentiment:  added stopwords"
filename = 'WordCld_neut_sent_stopwused.png'
make_wordcloud(data, title, filename, mask)

data = air_sub_df['stem_stopw_clean_text'][y=='neutral']
title = "Neutral sentiment:  added stemming"
filename = 'WordCld_neut_sent_stemused.png'
make_wordcloud(data, title, filename, mask)

# %% [markdown]
# ## Feature extraction using CountVectorizer()
# ```compare results of using 'clean text', 'added stopwords', and 'added stemming'.```<br>
# ```NOTE: I am passing a custom token pattern to the vectorizers because I want to```<br>
# ```use the emojis as features.```

# %% [markdown]
# ## Look at uni-grams

# %%
grams = "Unigrams"

# %%
# vectorize text with 'only cleaning' applied to it.
cv = CountVectorizer(ngram_range=(1,1))                     
X_cv = cv.fit_transform(air_sub_df['clean_text'])

words_df = pd.DataFrame(X_cv.toarray(), columns=cv.get_feature_names())
words_df.index = y

# vectorize text with 'stopwords' applied to it.
cv_stop = CountVectorizer(ngram_range=(1,1))
X_cv_stop = cv_stop.fit_transform(air_sub_df['stopw_clean_text'])

words_stop_df = pd.DataFrame(X_cv_stop.toarray(), columns=cv_stop.get_feature_names())
words_stop_df.index = y

# vectorize text 'with stemming' applied to it.
cv_stem = CountVectorizer(ngram_range=(1,1))
X_cv_stem = cv_stem.fit_transform(air_sub_df['stem_stopw_clean_text'])

words_stem_df = pd.DataFrame(X_cv_stem.toarray(), columns=cv_stem.get_feature_names())
words_stem_df.index = y

# %%
print(words_df.shape)
words_df.head(4)
# Out:
# (5112, 7678)
#                    006  0223  02282015  03  0303  03032015  0316  \
# airline_sentiment
# neutral              0     0         0   0     0         0     0
# neutral              0     0         0   0     0         0     0
# positive             0     0         0   0     0         0     0
# positive             0     0         0   0     0         0     0
#
#                    0372389047497  0400  0600    ...      yvonne  yvr  yyz  z1  \
# airline_sentiment                               ...
# neutral                        0     0     0    ...           0    0    0   0
# neutral                        0     0     0    ...           0    0    0   0
# positive                       0     0     0    ...           0    0    0   0
# positive                       0     0     0    ...           0    0    0   0
#
#                    zero  zfv  zip  zone  zoom  zurichnew
# airline_sentiment
# neutral               0    0    0     0     0          0
# neutral               0    0    0     0     0          0
# positive              0    0    0     0     0          0
# positive              0    0    0     0     0          0
#
# [4 rows x 7678 columns]

# %%
print(words_stop_df.shape)
words_stop_df.head(4)
# Out:
# (5112, 7421)
#                    006  0223  02282015  03  0303  03032015  0316  \
# airline_sentiment
# neutral              0     0         0   0     0         0     0
# neutral              0     0         0   0     0         0     0
# positive             0     0         0   0     0         0     0
# positive             0     0         0   0     0         0     0
#
#                    0372389047497  0400  0600    ...      yvonne  yvr  yyz  z1  \
# airline_sentiment                               ...
# neutral                        0     0     0    ...           0    0    0   0
# neutral                        0     0     0    ...           0    0    0   0
# positive                       0     0     0    ...           0    0    0   0
# positive                       0     0     0    ...           0    0    0   0
#
#                    zero  zfv  zip  zone  zoom  zurichnew
# airline_sentiment
# neutral               0    0    0     0     0          0
# neutral               0    0    0     0     0          0
# positive              0    0    0     0     0          0
# positive              0    0    0     0     0          0
#
# [4 rows x 7421 columns]

# %%
print(words_stem_df.shape)
words_stem_df.head(4)
# Out:
# (5112, 6029)
#                    006  0223  02282015  03  0303  03032015  0316  \
# airline_sentiment
# neutral              0     0         0   0     0         0     0
# neutral              0     0         0   0     0         0     0
# positive             0     0         0   0     0         0     0
# positive             0     0         0   0     0         0     0
#
#                    0372389047497  0400  0600    ...      yvonn  yvr  yyz  z1  \
# airline_sentiment                               ...
# neutral                        0     0     0    ...          0    0    0   0
# neutral                        0     0     0    ...          0    0    0   0
# positive                       0     0     0    ...          0    0    0   0
# positive                       0     0     0    ...          0    0    0   0
#
#                    zero  zfv  zip  zone  zoom  zurichnew
# airline_sentiment
# neutral               0    0    0     0     0          0
# neutral               0    0    0     0     0          0
# positive              0    0    0     0     0          0
# positive              0    0    0     0     0          0
#
# [4 rows x 6029 columns]

# %%
# We see that the dimensions of the features reduced from 7678 with clean text, 
# to 7421 with stopwords and 6029 with stemming.

# %% [markdown]
# ### Positive Sentiment

# %%
def disp_positive_grams(words_df, words_stop_df, words_stem_df, grams):

    words_sorted_ordimp = words_df[words_df.index == "positive"].\
                                                    sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Positive Sentiment: cleaned text', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_pos_sent_cleantext.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

    # added stopwords processing.
    words_sorted_ordimp = words_stop_df[words_stop_df.index == "positive"].\
                                                    sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Positive Sentiment: added stopwords', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_pos_sent_stopwused.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

    # with stemming.
    words_sorted_ordimp = words_stem_df[words_stem_df.index == "positive"].\
                                                        sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Positive Sentiment: added stemming', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_pos_sent_stemused.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

# %%
disp_positive_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['you', 'to', 'the', 'thanks', 'for', 'thank', 'emoji_45', 'and',
#        'flight', 'on', 'in', 'great', 'my', 'me', 'is', 'your', 'was', 'so',
#        'it', 'service', 'with', 'at', 'of', 'are', 'this', 'from', 'customer',
#        'good', 'that', 'have', 'all', 'just', 'guys', 'awesome', 'best',
#        'love', 'up', 'very', 'much', 'get', 'made', 'time', 'we', 'will', 'be',
#        'crew', 'today', 'us', 'amp', 'response'],
#       dtype='object')
# Index(['thanks', 'thank', 'emoji_45', 'great', 'service', 'customer', 'good',
#        'just', 'guys', 'best', 'awesome', 'love', 'time', 'crew', 'today',
#        'got', 'response', 'amazing', 'airline', 'work', 'appreciate', 'like',
#        'emoji_7', 'new', 'aa', 'team', 'yes', 'gate', 'job', 'helpful', 'help',
#        'flying', 'follow', 'im', 'home', 'tonight', 'emoji_3', 'emoji_44',
#        'really', 'did', 'fantastic', 'know', 'staff', 'appreciated', 'fly',
#        'emoji_5', 'big', 'airport', 'people', 'agent'],
#       dtype='object')
# Index(['thank', 'emoji_45', 'great', 'servic', 'love', 'help', 'custom', 'guy',
#        'good', 'just', 'work', 'best', 'awesom', 'appreci', 'crew', 'airlin',
#        'fli', 'time', 'today', 'respons', 'got', 'amaz', 'follow', 'like',
#        'emoji_7', 'make', 'aa', 'agent', 'new', 'team', 'ye', 'hope', 'job',
#        'im', 'gate', 'home', 'tonight', 'seat', 'know', 'emoji_3', 'emoji_44',
#        'attend', 'airport', 'safe', 'realli', 'did', 'problem', 'book',
#        'wonder', 'staff'],
#       dtype='object')

# %% [markdown]
# ## Negative

# %%
def disp_negative_grams(words_df, words_stop_df, words_stem_df, grams):

    # only cleaned text from formatting.
    words_sorted_ordimp = words_df[words_df.index == "negative"].\
                                                    sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Negative Sentiment: cleaned text', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_neg_sent_cleantext.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

    # added stopwords processing.
    words_sorted_ordimp = words_stop_df[words_stop_df.index == "negative"].\
                                                    sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Negative Sentiment: added stopwords', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_neg_sent_stopwused.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

    # with stemming.
    words_sorted_ordimp = words_stem_df[words_stem_df.index == "negative"].\
                                                        sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Negative Sentiment: added stemming', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_neg_sent_stemused.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

# %%
disp_negative_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['to', 'the', 'and', 'on', 'flight', 'for', 'you', 'my', 'is', 'in',
#        'of', 'me', 'no', 'your', 'not', 'have', 'it', 'was', 'at', 'that',
#        'get', 'this', 'cancelled', 'with', 'been', 'but', 'an', 'hold',
#        'service', 'now', 'hours', 'are', 'be', 'we', 'call', 'help',
#        'customer', 'from', 'up', 'us', 'can', 'just', 'do', 'time', 'they',
#        'flightled', 'still', 'cant', 'plane', 'amp'],
#       dtype='object')
# Index(['cancelled', 'hold', 'service', 'hours', 'help', 'customer', 'just',
#        'time', 'flightled', 'plane', 'phone', 'im', 'hour', 'delayed', 'gate',
#        'need', 'dont', 'late', 'waiting', 'bag', 'ive', 'trying', 'got',
#        'wait', 'minutes', 'airline', 'worst', 'guys', 'day', 'luggage', 'told',
#        'agent', 'thanks', 'going', 'weather', 'hrs', 'like', 'today', 'people',
#        'aa', 'delay', 'change', 'way', 'airport', 'home', 'days', 'really',
#        'line', 'flighted', 'sitting'],
#       dtype='object')
# Index(['hour', 'cancel', 'hold', 'servic', 'custom', 'delay', 'help', 'wait',
#        'time', 'bag', 'plane', 'just', 'flightl', 'tri', 'phone', 'day',
#        'need', 'im', 'gate', 'agent', 'dont', 'late', 'miss', 'ive', 'airlin',
#        'hr', 'call', 'fli', 'minut', 'thank', 'chang', 'min', 'got', 'seat',
#        'work', 'book', 'guy', 'sit', 'like', 'make', 'worst', 'luggag', 'told',
#        'today', 'weather', 'go', 'say', 'issu', 'peopl', 'rebook'],
#       dtype='object')

# %% [markdown]
# ## Neutral

# %%
def disp_neutral_grams(words_df, words_stop_df, words_stem_df, grams):

    # only cleaned text from formatting.
    words_sorted_ordimp = words_df[words_df.index == "neutral"].\
                                                    sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Neutral Sentiment: cleaned text', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_neut_sent_cleantext.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

    # added stopwords processing.
    words_sorted_ordimp = words_stop_df[words_stop_df.index == "neutral"].\
                                                    sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Neutral Sentiment: added stopwords', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_neut_sent_stopwused.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

    # with stemming.
    words_sorted_ordimp = words_stem_df[words_stem_df.index == "neutral"].\
                                                        sum().sort_values(ascending=False)
    words_sorted_ordimp.head(50).plot(kind='barh', title='Neutral Sentiment: added stemming', 
                                      figsize=(6,10), fontsize=12)
    plt.savefig(img_out_dir+grams+'_neut_sent_stemused.png')
    plt.show()
    # print top 30 features.
    print(words_sorted_ordimp[:50].index)

# %%
disp_neutral_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['to', 'the', 'flight', 'you', 'on', 'my', 'and', 'for', 'is', 'in',
#        'can', 'of', 'from', 'it', 'have', 'with', 'do', 'me', 'will', 'that',
#        'be', 'at', 'if', 'get', 'please', 'help', 'this', 'we', 'just', 'us',
#        'are', 'your', 'an', 'need', 'what', 'any', 'but', 'change', 'so',
#        'when', 'or', 'now', 'thanks', 'out', 'there', 'flights', 'not', 'no',
#        'was', 'im'],
#       dtype='object')
# Index(['help', 'just', 'need', 'change', 'thanks', 'im', 'cancelled', 'fly',
#        'dm', 'aa', 'know', 'tomorrow', 'like', 'airport', 'way', 'new',
#        'number', 'email', 'did', 'service', 'travel', 'hi', 'dfw', 'ceo',
#        'time', 'booked', 'american', 'ticket', 'flying', 'weather', 'airways',
#        'today', 'wall', 'guys', 'bag', 'flightled', 'make', 'jfk', 'use',
#        'whats', 'passengers', 'check', 'morning', 'seats', 'book', 'add',
#        'reservation', 'sent', 'want', 'journal'],
#       dtype='object')
# Index(['help', 'thank', 'fli', 'just', 'need', 'chang', 'travel', 'book', 'im',
#        'cancel', 'ticket', 'aa', 'dm', 'use', 'know', 'tomorrow', 'like',
#        'airport', 'way', 'email', 'check', 'look', 'reserv', 'new', 'connect',
#        'follow', 'time', 'number', 'seat', 'did', 'servic', 'ceo', 'plane',
#        'american', 'bag', 'hi', 'dfw', 'today', 'delay', 'airway', 'weather',
#        'make', 'want', 'wall', 'depart', 'guy', 'offer', 'jfk', 'what',
#        'passeng'],
#       dtype='object')

# %% [markdown]
# # Look at bi-grams

# %%
grams = "Bigrams"

# %%
# vectorize text with 'only cleaning' applied to it.
cv = CountVectorizer(ngram_range=(2,2))
X_cv = cv.fit_transform(air_sub_df['clean_text'])

words_df = pd.DataFrame(X_cv.toarray(), columns=cv.get_feature_names())
words_df.index = y

# vectorize text with 'stopwords' applied to it.
cv_stop = CountVectorizer(ngram_range=(2,2))
X_cv_stop = cv_stop.fit_transform(air_sub_df['stopw_clean_text'])

words_stop_df = pd.DataFrame(X_cv_stop.toarray(), columns=cv_stop.get_feature_names())
words_stop_df.index = y

# vectorize text 'with stemming' applied to it.
cv_stem = CountVectorizer(ngram_range=(2,2))
X_cv_stem = cv_stem.fit_transform(air_sub_df['stem_stopw_clean_text'])

words_stem_df = pd.DataFrame(X_cv_stem.toarray(), columns=cv_stem.get_feature_names())
words_stem_df.index = y

# %%
print(words_df.shape)
words_df.head(4)
# Out:
# (5112, 42204)
#                    006 on  0223 got  02282015 until  03 back  0303 can  \
# airline_sentiment
# neutral                 0         0               0        0         0
# neutral                 0         0               0        0         0
# positive                0         0               0        0         0
# positive                0         0               0        0         0
#
#                    03032015 and  0316 am  0372389047497 totally  0600 wont  \
# airline_sentiment
# neutral                       0        0                      0          0
# neutral                       0        0                      0          0
# positive                      0        0                      0          0
# positive                      0        0                      0          0
#
#                    0671 strand       ...        zero information  \
# airline_sentiment                    ...
# neutral                      0       ...                       0
# neutral                      0       ...                       0
# positive                     0       ...                       0
# positive                     0       ...                       0
#
#                    zero respect  zero response  zero success  zfv yyz  \
# airline_sentiment
# neutral                       0              0             0        0
# neutral                       0              0             0        0
# positive                      0              0             0        0
# positive                      0              0             0        0
#
#                    zone boarded  zone change  zone was  zoom in  \
# airline_sentiment
# neutral                       0            0         0        0
# neutral                       0            0         0        0
# positive                      0            0         0        0
# positive                      0            0         0        0
#
#                    zurichnew york
# airline_sentiment
# neutral                         0
# neutral                         0
# positive                        0
# positive                        0
#
# [4 rows x 42204 columns]

# %%
print(words_stop_df.shape)
words_stop_df.head(1)
# Out:
# (5112, 29865)
#                    006 news  0223 got  02282015 03032015  03 forth  0303 help  \
# airline_sentiment
# neutral                   0         0                  0         0          0
#
#                    03032015 dont  0372389047497 totally  0600 wont  \
# airline_sentiment
# neutral                        0                      0          0
#
#                    0671 strand  10 advice       ...        zero information  \
# airline_sentiment                               ...
# neutral                      0          0       ...                       0
#
#                    zero respect  zero response  zero success  zfv yyz  \
# airline_sentiment
# neutral                       0              0             0        0
#
#                    zone boarded  zone change  zone precious  zoom sauce  \
# airline_sentiment
# neutral                       0            0              0           0
#
#                    zurichnew york
# airline_sentiment
# neutral                         0
#
# [1 rows x 29865 columns]

# %%
print(words_stem_df.shape)
words_stem_df.head(4)
# Out:
# (5112, 28450)
#                    006 news  0223 got  02282015 03032015  03 forth  0303 help  \
# airline_sentiment
# neutral                   0         0                  0         0          0
# neutral                   0         0                  0         0          0
# positive                  0         0                  0         0          0
# positive                  0         0                  0         0          0
#
#                    03032015 dont  0372389047497 total  0600 wont  0671 strand  \
# airline_sentiment
# neutral                        0                    0          0            0
# neutral                        0                    0          0            0
# positive                       0                    0          0            0
# positive                       0                    0          0            0
#
#                    10 advic       ...        zero inform  zero respect  \
# airline_sentiment                 ...
# neutral                   0       ...                  0             0
# neutral                   0       ...                  0             0
# positive                  0       ...                  0             0
# positive                  0       ...                  0             0
#
#                    zero respons  zero success  zfv yyz  zone board  \
# airline_sentiment
# neutral                       0             0        0           0
# neutral                       0             0        0           0
# positive                      0             0        0           0
# positive                      0             0        0           0
#
#                    zone chang  zone preciou  zoom sauc  zurichnew york
# airline_sentiment
# neutral                     0             0          0               0
# neutral                     0             0          0               0
# positive                    0             0          0               0
# positive                    0             0          0               0
#
# [4 rows x 28450 columns]

# %%
# Feature dimension reduced from 42204 with cleaned text, to 29865 with stopwords and
# 28450 with stemming.

# %% [markdown]
# ## Positive

# %%
disp_positive_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['thank you', 'emoji_45 emoji_45', 'thanks for', 'for the', 'you for',
#        'customer service', 'you guys', 'the best', 'thanks to', 'to the',
#        'in the', 'so much', 'are the', 'you are', 'to get', 'on the',
#        'follow me', 'made it', 'on flight', 'for your', 'of the', 'me please',
#        'flight to', 'guys are', 'good work', 'with you', 'please emoji_45',
#        'emoji_5 emoji_5', 'emoji_7 emoji_7', 'the good', 'emoji_44 emoji_44',
#        'this is', 'you so', 'great flight', 'my flight', 'you have', 'keep up',
#        'on time', 'the response', 'great job', 'kudos to', 'this morning',
#        'able to', 'very much', 'flight attendant', 'up the',
#        'booking problems', 'the phone', 'has been', 'the flight'],
#       dtype='object')
# Index(['emoji_45 emoji_45', 'customer service', 'follow emoji_45',
#        'emoji_5 emoji_5', 'good work', 'emoji_44 emoji_44', 'emoji_7 emoji_7',
#        'great job', 'awesome thanks', 'booking problems', 'best follow',
#        'great thank', 'social media', 'emoji_45 emoji_44', 'great thanks',
#        'great service', 'great crew', 'thanks great', 'emoji_3 emoji_3',
#        'quick response', 'prompt response', 'thanks response',
#        'appreciate prompt', 'big thanks', 'guys best', 'guys rock',
#        'thanks help', 'gate agent', 'thank help', 'great customer',
#        'service today', 'emoji_44 emoji_45', 'excellent customer',
#        'just received', 'big thank', 'free wifi', 'american airlines',
#        'best airline', 'reflight booking', 'amazing follow', 'best airways',
#        'did great', 'just wanted', 'staff amazing', 'thank aa', 'great time',
#        'gate agents', 'bos sfo', 'great people', 'airways follow'],
#       dtype='object')
# Index(['emoji_45 emoji_45', 'custom servic', 'thank help', 'great thank',
#        'follow emoji_45', 'emoji_5 emoji_5', 'good work', 'emoji_7 emoji_7',
#        'emoji_44 emoji_44', 'gate agent', 'great job', 'big thank',
#        'awesom thank', 'thank great', 'thank respons', 'book problem',
#        'quick respons', 'emoji_45 emoji_44', 'emoji_3 emoji_3', 'great servic',
#        'thank aa', 'great crew', 'social media', 'best follow',
#        'emoji_44 emoji_45', 'thank crew', 'prompt respons', 'servic today',
#        'guy best', 'best airlin', 'just want', 'appreci prompt',
#        'american airlin', 'guy rock', 'excel custom', 'thank quick',
#        'thank good', 'fli guy', 'great custom', 'today thank', 'thank updat',
#        'thank share', 'thank repli', 'jet blue', 'ye thank', 'airway follow',
#        'servic thank', 'best airway', 'thank hope', 'job today'],
#       dtype='object')

# %% [markdown]
# ## Negative

# %%
disp_negative_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['on hold', 'cancelled flightled', 'customer service', 'on the',
#        'my flight', 'to get', 'hold for', 'to be', 'this is', 'trying to',
#        'been on', 'an hour', 'you guys', 'have been', 'the phone', 'need to',
#        'late flight', 'due to', 'to the', 'cancelled flighted', 'in the',
#        'for the', 'out of', 'the plane', 'up on', 'my bag', 'ive been',
#        'to call', 'call back', 'me to', 'late flightr', 'waiting for',
#        'the worst', 'was cancelled', 'for hours', 'at the', 'going to',
#        'have to', 'cant get', 'thanks for', 'no one', 'has been', 'you have',
#        'is the', 'for over', 'flight to', 'the gate', 'the flight', 'want to',
#        'had to'],
#       dtype='object')
# Index(['cancelled flightled', 'customer service', 'cancelled flighted',
#        'late flightr', 'hold hours', 'ive hold', 'booking problems',
#        'gate agent', 'hold hour', 'hours late', 'worst customer', 'hours hold',
#        'sitting plane', '30 minutes', 'worst airline', 'need help',
#        'hour delay', '24 hours', 'dividend miles', 'wait time', 'bad weather',
#        '30 min', 'baggage claim', 'just want', 'miss connection', 'hour wait',
#        '30 mins', 'wont let', 'worst experience', 'minutes hold',
#        'delayed hours', 'cancelled flightlations', 'gate agents', 'hour half',
#        '45 minutes', 'reflight booking', 'ive trying', 'hold hrs',
#        'poor customer', '800 number', 'hold 30', 'mechanical issues',
#        'dont want', '40 minutes', 'cancelled flighting', '12 hours',
#        'dont care', 'trying change', 'customer relations', 'im trying'],
#       dtype='object')
# Index(['cancel flightl', 'custom servic', 'cancel flight', 'hold hour',
#        'late flightr', 'miss connect', 'gate agent', 'hour late', 'ive hold',
#        'hour hold', 'wait hour', 'book problem', 'hour wait', '30 min',
#        'worst custom', 'sit plane', 'hour delay', 'answer phone',
#        'cancel flightlat', 'check bag', '30 minut', 'ive tri', 'worst airlin',
#        '24 hour', 'wait time', 'need help', 'delay hour', 'dividend mile',
#        'baggag claim', 'plane hour', 'wait hold', 'minut hold', '45 min',
#        'bad weather', 'look like', 'mechan issu', 'just want', '45 minut',
#        'worst experi', 'hold hr', 'poor custom', 'cancel flightat', '12 hour',
#        'wont let', '40 minut', '800 number', 'hour half', 'reflight book',
#        'lost bag', 'hold 30'],
#       dtype='object')

# %% [markdown]
# ## Neutral

# %%
disp_neutral_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['can you', 'do you', 'need to', 'in the', 'my flight', 'to the',
#        'on the', 'out of', 'is there', 'the flight', 'on my', 'to change',
#        'you have', 'is the', 'cancelled flightled', 'will be', 'is it',
#        'for the', 'you help', 'to get', 'thank you', 'help me', 'of the',
#        'can get', 'it to', 'you guys', 'passengers and', 'wall street',
#        'and wall', 'for tomorrow', 'ceo battles', 'battles to', 'if you',
#        'can dm', 'have to', 'so can', 'appease passengers', 'us airways',
#        'on your', 'whats the', 'to be', 'want to', 'to appease', 'at the',
#        'on flight', 'are you', 'what is', 'to my', 'to fly', 'flight to'],
#       dtype='object')
# Index(['cancelled flightled', 'passengers wall', 'wall street', 'ceo battles',
#        'appease passengers', 'battles appease', 'booking problems',
#        'need help', 'follow dm', 'offer inflight', 'street waterbury',
#        'american airlines', 'team offer', 'inflight access',
#        'republican american', 'customer service', 'credit card',
#        'waterbury republican', 'digital journal', 'email address',
#        'access journal', 'travel advisory', 'lufthansa incentive', 'we ll',
#        'thinking summer', 'summer new', 'late flightr', 'new nantucket',
#        'cancelled flighted', 'got new', 'dc thinking', 'nantucket service',
#        'just landed', 'id like', 'just sent', 'airways corporation',
#        'frequent flyer', 'looks like', 'let know', 'need change',
#        'incentive offer', 'departs enroute', 'record locator', 'washington dc',
#        'theyd flown', 'known traveler', 'just passed', 'weather humor',
#        'cheaper airfare', 'flown south'],
#       dtype='object')
# Index(['cancel flightl', 'passeng wall', 'wall street', 'ceo battl',
#        'need help', 'appeas passeng', 'battl appeas', 'book problem',
#        'cancel flight', 'follow dm', 'email address', 'waterburi republican',
#        'inflight access', 'team offer', 'travel advisori', 'american airlin',
#        'street waterburi', 'republican american', 'custom servic',
#        'offer inflight', 'look like', 'credit card', 'access journal',
#        'digit journal', 'washington dc', 'late flightr', 'let know', 'we ll',
#        'got new', 'lufthansa incent', 'chanc make', 'delay cancel',
#        'summer new', 'dc think', 'nantucket servic', 'new nantucket',
#        'need chang', 'think summer', 'id like', 'just sent', 'just land',
#        'airway corpor', 'depart enrout', 'record locat', 'incent offer',
#        'frequent flyer', 'tsa pre', 'what statu', 'did know', 'dfw lex'],
#       dtype='object')

# %% [markdown]
# # Look at tri-grams

# %%
grams = "Trigrams"

# %%
# vectorize text with 'only cleaning' applied to it.
cv = CountVectorizer(ngram_range=(3,3))
X_cv = cv.fit_transform(air_sub_df['clean_text'])

words_df = pd.DataFrame(X_cv.toarray(), columns=cv.get_feature_names())
words_df.index = y

# vectorize text with 'stopwords' applied to it.
cv_stop = CountVectorizer(ngram_range=(3,3))
X_cv_stop = cv_stop.fit_transform(air_sub_df['stopw_clean_text'])

words_stop_df = pd.DataFrame(X_cv_stop.toarray(), columns=cv_stop.get_feature_names())
words_stop_df.index = y

# vectorize text 'with stemming' applied to it.
cv_stem = CountVectorizer(ngram_range=(3,3))
X_cv_stem = cv_stem.fit_transform(air_sub_df['stem_stopw_clean_text'])

words_stem_df = pd.DataFrame(X_cv_stem.toarray(), columns=cv_stem.get_feature_names())
words_stem_df.index = y

# %%
# with stemming feature dimensionality reduced from 31667 to 31471.

# %%
print(words_df.shape)
words_df.head(1)
# Out:
# (5112, 62990)
#                    006 on news  0223 got cncled  02282015 until the  \
# airline_sentiment
# neutral                      0                0                   0
#
#                    03 back and  0303 can you  03032015 and they  \
# airline_sentiment
# neutral                      0             0                  0
#
#                    0372389047497 totally unacceptable  0600 wont let  \
# airline_sentiment
# neutral                                             0              0
#
#                    0671 strand me  10 am office          ...            \
# airline_sentiment                                        ...
# neutral                         0             0          ...
#
#                    zero information please  zero respect for  \
# airline_sentiment
# neutral                                  0                 0
#
#                    zero response from  zero response never  zfv yyz usairways  \
# airline_sentiment
# neutral                             0                    0                  0
#
#                    zone boarded overhead  zone change to  zone was after  \
# airline_sentiment
# neutral                                0               0               0
#
#                    zoom in on  zurichnew york thanks
# airline_sentiment
# neutral                     0                      0
#
# [1 rows x 62990 columns]

# %%
print(words_stop_df.shape)
words_stop_df.head(1)
# Out:
# (5112, 30405)
#                    006 news airways  0223 got cncled  02282015 03032015 dont  \
# airline_sentiment
# neutral                           0                0                       0
#
#                    03 forth gatwick  03032015 dont want  \
# airline_sentiment
# neutral                           0                   0
#
#                    0372389047497 totally unacceptable  0600 wont let  \
# airline_sentiment
# neutral                                             0              0
#
#                    0671 strand phx  10 al shes  10 bucks middle  \
# airline_sentiment
# neutral                          0           0                0
#
#                            ...            zero information send  \
# airline_sentiment          ...
# neutral                    ...                                0
#
#                    zero respect passengers  zero response traveling  \
# airline_sentiment
# neutral                                  0                        0
#
#                    zero response tweet  zfv yyz baggagelost  \
# airline_sentiment
# neutral                              0                    0
#
#                    zone boarded overhead  zone change est  zone precious gems  \
# airline_sentiment
# neutral                                0                0                   0
#
#                    zoom sauce potatoes  zurichnew york thanks
# airline_sentiment
# neutral                              0                      0
#
# [1 rows x 30405 columns]

# %%
print(words_stem_df.shape)
words_stem_df.head(1)
# Out:
# (5112, 30197)
#                    006 news airway  0223 got cncled  02282015 03032015 dont  \
# airline_sentiment
# neutral                          0                0                       0
#
#                    03 forth gatwick  03032015 dont want  \
# airline_sentiment
# neutral                           0                   0
#
#                    0372389047497 total unaccept  0600 wont let  \
# airline_sentiment
# neutral                                       0              0
#
#                    0671 strand phx  10 al she  10 buck middl  \
# airline_sentiment
# neutral                          0          0              0
#
#                            ...           zero inform send  \
# airline_sentiment          ...
# neutral                    ...                          0
#
#                    zero respect passeng  zero respons travel  \
# airline_sentiment
# neutral                               0                    0
#
#                    zero respons tweet  zfv yyz baggagelost  \
# airline_sentiment
# neutral                             0                    0
#
#                    zone board overhead  zone chang est  zone preciou gem  \
# airline_sentiment
# neutral                              0               0                 0
#
#                    zoom sauc potato  zurichnew york thank
# airline_sentiment
# neutral                           0                     0
#
# [1 rows x 30197 columns]

# %%
# dimensionality reduced from 62990, to 30405, 30197

# %% [markdown]
# ## Positive

# %%
disp_positive_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['emoji_45 emoji_45 emoji_45', 'thank you for', 'thanks for the',
#        'are the best', 'you for the', 'you are the',
#        'please emoji_45 emoji_45', 'you so much', 'you guys are',
#        'thank you so', 'follow me please', 'thanks to the',
#        'me please emoji_45', 'up the good', 'keep up the',
#        'emoji_5 emoji_5 emoji_5', 'the good work', 'emoji_7 emoji_7 emoji_7',
#        'thanks so much', 'for your help', 'thanks for your', 'the best follow',
#        'best follow me', 'for the response', 'emoji_45 emoji_45 emoji_44',
#        'from bos to', 'great thank you', 'with you guys', 'thank you very',
#        'follow me back', 'thank you you', 'you are amazing',
#        'great customer service', 'excellent customer service',
#        'emoji_44 emoji_44 emoji_44', 'crew on flight', 'on the phone',
#        'emoji_45 emoji_44 emoji_44', 'emoji_44 emoji_44 emoji_45',
#        'for the quick', 'emoji_44 emoji_45 emoji_45', 'you guys rock',
#        'to the crew', 'the quick response', 'you for your', 'in the terminal',
#        'do the same', 'for getting me', 'will thank you', 'for the update'],
#       dtype='object')
# Index(['emoji_45 emoji_45 emoji_45', 'follow emoji_45 emoji_45',
#        'emoji_5 emoji_5 emoji_5', 'emoji_7 emoji_7 emoji_7',
#        'emoji_45 emoji_45 emoji_44', 'emoji_44 emoji_45 emoji_45',
#        'great customer service', 'emoji_44 emoji_44 emoji_45',
#        'emoji_44 emoji_44 emoji_44', 'best follow emoji_45',
#        'excellent customer service', 'emoji_45 emoji_44 emoji_44',
#        'appreciate prompt response', 'did great job',
#        'emoji_3 emoji_3 emoji_3', 'reflight booking problems',
#        'airways follow emoji_45', 'best airways follow',
#        'customer service today', 'emoji_45 emoji_45 emoji_5',
#        'emoji_45 emoji_5 emoji_5', 'emoji_5 emoji_5 emoji_45',
#        'airport snow removal', 'thanks aadfw gma', 'emoji_5 emoji_45 emoji_45',
#        'just missing good', 'thanks gate agent', 'photos thanks sharing',
#        'airline im able', 'new plane gogo', 'aa airline im',
#        'understand btw aa', 'aa dallas airline', 'boatstyle swivel cup',
#        'easy power laptop', 'folks cessnas 747s', 'flying aa dallas',
#        'booking problems friends', 'deane norma sedholm',
#        'amazing follow emoji_45', 'thanks guys got', 'amazing best follow',
#        'gogo easy power', 'gma amso understand', 'removal method 22',
#        'awesome customer service', 'awesome photos thanks', 'aww thanks aadfw',
#        'good boatstyle swivel', 'exceptional customer service'],
#       dtype='object')
# Index(['emoji_45 emoji_45 emoji_45', 'follow emoji_45 emoji_45',
#        'emoji_5 emoji_5 emoji_5', 'emoji_7 emoji_7 emoji_7',
#        'emoji_45 emoji_45 emoji_44', 'emoji_45 emoji_44 emoji_44',
#        'emoji_44 emoji_45 emoji_45', 'emoji_44 emoji_44 emoji_45',
#        'emoji_44 emoji_44 emoji_44', 'excel custom servic',
#        'great custom servic', 'best follow emoji_45', 'appreci prompt respons',
#        'airway follow emoji_45', 'custom servic today', 'best airway follow',
#        'thank quick respons', 'did great job', 'reflight book problem',
#        'emoji_3 emoji_3 emoji_3', 'custom servic thank',
#        'holder dietcok happyfli', 'dean norma sedholm', 'amaz follow emoji_45',
#        'amaz custom servic', 'method 22 good', 'amaz best follow',
#        'great job today', 'airport snow remov', 'power laptop iphon',
#        'custom servic rep', 'emoji_45 emoji_5 emoji_5', 'photo thank share',
#        'just want say', 'plane gogo easi', 'amso understand btw',
#        'laptop iphon just', 'thank guy got', 'thank gate agent',
#        'airlin im abl', 'iphon just miss', 'exactli ill fli', 'fli aa dalla',
#        'david dean norma', 'snow remov method', 'except custom servic',
#        'thank aadfw gma', 'cup holder dietcok', 'abl trvlove guy',
#        'thank final got'],
#       dtype='object')

# %% [markdown]
# ## Negative

# %%
disp_negative_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['on hold for', 'been on hold', 'was cancelled flightled',
#        'on the phone', 'ive been on', 'hung up on', 'your customer service',
#        'on the plane', 'for an hour', 'over an hour', 'flight was cancelled',
#        'up on me', 'been trying to', 'trying to get', 'to speak to',
#        'cancelled flightled flight', 'worst customer service', 'to talk to',
#        'to get to', 'customer service is', 'hold for over', 'sitting on the',
#        'at the gate', 'hours on hold', 'flight cancelled flightled',
#        'hold for hours', 'my flight was', 'cancelled flightled my',
#        'cancelled flightled and', 'flight booking problems',
#        'cant get through', 'to cancelled flight', 'to call back',
#        'get through to', 'to get home', 'for over an', 'have been on',
#        'and no one', 'this is the', 'due to weather', 'at the airport',
#        'hours late flightr', 'is the worst', 'going to be', 'on the tarmac',
#        'you cancelled flightled', 'can you help', 'flightled my flight',
#        'thanks for the', 'to speak with'],
#       dtype='object')
# Index(['worst customer service', 'hours late flightr',
#        'reflight booking problems', 'poor customer service',
#        'terrible customer service', 'cancelled flightled yesterday',
#        'dfw cancelled flightled', 'got cancelled flightled',
#        'going miss connection', 'weather relate flightd', 'ive hold hour',
#        'cancelled flightled hold', 'horrible customer service',
#        'cancelled flightled tomorrow', 'customer service agents',
#        'customer service line', 'hold 30 minutes', 'cancelled flightled got',
#        'try late flightr', 'customer service rep', 'hold 90 minutes',
#        'gate agent said', 'sitting plane hour', 'hrs late flightr',
#        'tomorrow cancelled flightled', 'hold 15 hours',
#        'worst flying experience', 'bad weather happens',
#        'tomorrow cancelled flighted', 'delays cancelled flightlations',
#        'got cancelled flighted', 'talk real person',
#        'today cancelled flightled', 'hold 30 min', 'hold hours trying',
#        'hold customer service', 'trying speak agent',
#        'customer service experience', 'bad customer service',
#        'cancelled flightled need', 'thanks cancelled flightled',
#        'cancelled flightled rescheduled', 'hour wait time', 'just want home',
#        'rebook cancelled flightled', 'hold 45 minutes', 'told late flightr',
#        'worst airline travel', 'trying change reservation',
#        'cancelled flighted tomorrow'],
#       dtype='object')
# Index(['worst custom servic', 'hour late flightr', 'poor custom servic',
#        'reflight book problem', 'sit plane hour', 'ive hold hour',
#        'terribl custom servic', 'hold 30 min', 'custom servic agent',
#        'cancel flightl yesterday', 'got cancel flightl', 'dfw cancel flightl',
#        'go miss connect', 'custom servic rep', 'hold hour tri',
#        'cancel flightl hold', 'custom servic line', 'hold 30 minut',
#        'weather relat flightd', 'horribl custom servic',
#        'cancel flightl tomorrow', 'hold 90 minut', 'gate agent said',
#        'cancel flightl got', 'hr late flightr', 'min late flightr',
#        'worst fli experi', 'wait hold hour', 'tomorrow cancel flight',
#        'rebook cancel flightl', 'tri late flightr', 'cancel flightl ticket',
#        'cancel flightl make', 'cancel flightl reschedul',
#        'delay cancel flightlat', 'tell late flightr', 'miss day work',
#        'bad custom servic', 'today cancel flightl', 'cancel flightl rebook',
#        'got cancel flight', 'hour hold time', 'email custom servic',
#        'just want home', 'hold custom servic', 'hour wait time',
#        'delay mechan issu', 'custom servic experi', 'cancel flightl need',
#        'cancel flightl tri'],
#       dtype='object')

# %% [markdown]
# ## Neutral

# %%
disp_neutral_grams(words_df, words_stop_df, words_stem_df, grams)
# Out:
# Index(['can you help', 'passengers and wall', 'ceo battles to', 'do you have',
#        'battles to appease', 'appease passengers and', 'and wall street',
#        'to appease passengers', 'can dm you', 'so can dm',
#        'flight booking problems', 'you help me', 'team to offer',
#        'what is the', 'to offer inflight', 'inflight access to',
#        'any chance of', 'waterbury republican american', 'and the from',
#        'the from team', 'access to journal', 'is it possible',
#        'street waterbury republican', 'if the flight', 'offer inflight access',
#        'wall street waterbury', 'from team to', 'can you please',
#        'it possible to', 'the flight is', 'with new nantucket',
#        'from us airways', 'thinking about summer', 'dc thinking about',
#        'lufthansa incentive offer', 'please follow me', 'summer with new',
#        'follow me so', 'has dc thinking', 'be able to', 'me so can',
#        'is there way', 'with the flight', 'the status of', 'can you dm',
#        'can you tell', 'is there any', 'be cancelled flightled',
#        'on my flight', 'you tell me'],
#       dtype='object')
# Index(['appease passengers wall', 'ceo battles appease',
#        'passengers wall street', 'battles appease passengers',
#        'street waterbury republican', 'offer inflight access',
#        'wall street waterbury', 'inflight access journal',
#        'waterbury republican american', 'team offer inflight',
#        'thinking summer new', 'lufthansa incentive offer',
#        'summer new nantucket', 'dc thinking summer', 'new nantucket service',
#        'access journal digital', 'dfw lex tomorrow', 'got cancelled flightled',
#        'got new license', 'we ll tweeting', 'new marketing song',
#        'new license booked', 'new ceo seeks', 'leading cause death',
#        'add fees sit', 'did know suicide', 'leaving hours emoji_45',
#        'cancelled flightled grk', 'wish theyd flown', 'cause death teens',
#        'grk dfw lex', 'know suicide second', 'recently moved got',
#        'way cheaper airfare', 'just disappointed booking', 'death teens 1024',
#        'just little cold', 'deflator specified chapter', 'just passed need',
#        'delays cancelled flightlations', 'ticket leaving hours',
#        'ceo weighs profits', 'aa199 mxpjfk feb', 'ceo seeks right',
#        'ceo pilots ardent', 'thought planes retired', 'know just little',
#        'aa gate supervisor', 'let know think', 'theyd flown south'],
#       dtype='object')
# Index(['passeng wall street', 'appeas passeng wall', 'battl appeas passeng',
#        'ceo battl appeas', 'wall street waterburi', 'team offer inflight',
#        'inflight access journal', 'waterburi republican american',
#        'offer inflight access', 'street waterburi republican',
#        'summer new nantucket', 'dc think summer', 'lufthansa incent offer',
#        'new nantucket servic', 'think summer new', 'cheaper airfar ticket',
#        'model pn 320008a', 'old licens need', 'probabl way cheaper',
#        '32 b787 amm', 'space aa199 mxpjfk', 'journal digit journal',
#        '320008a wheel deflat', 'got new licens', 'problem process add',
#        'aa199 mxpjfk feb', 'know probabl way', 'way cheaper airfar',
#        'tomorrow need rebook', 'know suicid second', 'book award travel',
#        'use old licens', 'process add fee', 'chapter 32 b787',
#        'caus death teen', 'song let know', 'profit flyer registr',
#        'street poughkeepsi journal', 'book month ago', 'month ago use',
#        'deflat specifi chapter', 'ceo weigh profit', 'ceo seek right',
#        'thought plane retir', 'ceo pilot ardent', 'flown south winter',
#        'statement lufthansa incent', 'mxpjfk feb 28th', 'move got new',
#        'run io 813'],
#       dtype='object')

# %%
# Pickle dataframe with added columns with processed and cleaned text.
import pickle

# %%
filename = data_out_dir+'airline_cl_process_dataset_df2'
filehandler = open(filename,"wb")
pickle.dump(air_sub_df,filehandler)

# %%
file = open(filename,'rb')
object_content = pickle.load(file)

# %%
#**************** I did not encode emojis. What did count vectorizer do with them? Let's explore.

# %%
# emoji in text.
text1 = air_sub_df.loc[8002, 'clean_text']
text2 = air_sub_df.loc[8001, 'stopw_clean_text']

# %%
text1, text2
# Out:
# ('he loved the natural beefjerky snacks EMOJI_35',
#  'im flying airline just lga EMOJI_79')

# %%
def disp_transformed_text_tokens(vectorizer, text):
    text_vect = vectorizer.transform([text])
    text_df = pd.DataFrame(text_vect.toarray(), columns=vectorizer.get_feature_names())
    words = text_df.sum().sort_values(ascending=False)
    words.head(10).plot(kind='barh',figsize=(3,4), fontsize=12)
    print(text)
    plt.show()

# %%
disp_transformed_text_tokens(cv, text1)
disp_transformed_text_tokens(cv, text2)
# Out:
# he loved the natural beefjerky snacks EMOJI_35
# im flying airline just lga EMOJI_79

# %%
reverse_lookup_emoji_dict['EMOJI_79'], reverse_lookup_emoji_dict['EMOJI_35']
# Out:
# ('😷', '😉')

# %%
# Emojis are encoded. Now use this data for modelling and see what effects
# emojis have. on predictions. Explore this further in another notebook.
